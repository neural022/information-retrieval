# %% [markdown]
# # Import Package

# %%
import sys
from os.path import join
from numba import jit
import numpy as np
import pandas as pd
import datetime

# %run psesudo_relevance_feedback.ipynb

# %% [markdown]
# # Load Data and Preprocess and Calculate Time Function

# %%
def get_file_list(file_list_path):

    file_list = list()        
    with open(file_list_path, 'r', encoding='UTF-8') as f:
        for file_id in f.readlines():
            file_list.append(file_id.strip('\n'))
    f.close()        
    return file_list

def load_data(file_list, file_path):
    
    data = list()
    for file_id in file_list:
        with open(join(file_path, file_id+'.txt'), 'r', encoding='UTF-8') as f:
            data.append(f.read())
        f.close()
    return data

def load_pseudo_relevant_docs(file_path, top_ranked=10, odd=False):
    prdocs_list = dict()
    df = pd.read_csv(file_path)
    
    for indexs in df.index:
        rowData = df.loc[indexs].values[0:2]
        rowData = rowData.tolist()
        query_id = rowData[0]
        if odd:
            rowData = rowData[1].split()[::2]
            docs_id = rowData[0:top_ranked]
        else:
            docs_id = rowData[1].split()[0:top_ranked]
        prdocs_list[query_id] = docs_id
        
    return prdocs_list

def cut(text):
    return text.split()

def now_time():
    return datetime.datetime.now()

def cost_time(start_time, end_time):
    cost_time = end_time - start_time
    print('Cost time: %s\n' % cost_time)
    
def progressbar(it, prefix="", size=60, file=sys.stdout):
    count = len(it)
    def show(j):
        x = int(size*j/count)
        file.write("%s[%s%s] %i/%i\r" % (prefix, "#"*x, "."*(size-x), j, count))
        file.flush()        
    show(0)
    for i, item in enumerate(it):
        yield item
        show(i+1)
    file.write("\n")
    file.flush()

# %% [markdown]
# # SMM Function

# %%
def random_initial(row):  
    # uniform distribution
    np_array = np.random.rand(row)
    '''
    e.g prob = [ 0.7, 0.6, 0.3 ]
    sum = 1.6
    x1 = 0.7 / 1.6 = 0.4375
    x2 = 0.6 / 1.6 = 0.375
    x3 = 0.3 / 1.6 = 0.1875
    Σ summation(x1, x2, x3) = 1 
    '''
    # axis = 0:sum of row
    # axis = 1: sum of column        
    return np_array / np_array.sum(axis=0, keepdims=True)


# Probabilistic Simple Mixture Model
@jit(nopython=True)
def smm(word_Tsmm_prob, word_bg_prob, coo_row, coo_col, coo_data, alpha, iter_num):
    
    # term_doc matrix's row is word w(i) 
    # term_doc matrix's column is document d(j)
    
    # print(len(coo_row), len(coo_col), len(coo_data))
    ''' P(Tsmm | wi) for each query '''
    Tsmm_word_prob = np.zeros((word_Tsmm_prob.shape[0]))
    ''' P(Tsmm) '''
    Tsmm_prob = 1-alpha
    ''' P(BG) '''
    bg_prob = alpha
    
    # EM Algorithm
    print("Iteration Start:")
    for iter_index in range(iter_num):
        # E step
        for i in range(word_Tsmm_prob.shape[0]):      
            '''  P(wi | Tsmm) * P(Tsmm) / ( P(wi | Tsmm) * P(Tsmm) + P(wi | BG) * P(BG) ) '''
            Tsmm_word_prob[i] = (word_Tsmm_prob[i] * Tsmm_prob) / (word_Tsmm_prob[i] * Tsmm_prob + word_bg_prob[i] * bg_prob)
                
        # M step
        
        # initial zero
        word_Tsmm_prob.fill(0)
        Tsmm_sum = 0
        
        for i in range(len(coo_data)):
            w_coord = coo_row[i]
            # d_coord = coo_col[i]
            term_freq = coo_data[i]
            # 
            tf_tw = term_freq * Tsmm_word_prob[w_coord]
            ''' P(wi | Tsmm) '''
            word_Tsmm_prob[w_coord] += tf_tw
            Tsmm_sum += tf_tw

        for i in range(word_Tsmm_prob.shape[0]):
             word_Tsmm_prob[i] /= Tsmm_sum
                
        # log likelihood (Multiply to Add)
        likelihood_sum = 0
        for i in range(len(coo_data)):            
            w_coord = coo_row[i]
            # d_coord = coo_col[i]
            term_freq = coo_data[i]
            ''' P(wi | Tsmm) * P(Tsmm) + P(wi | BG) * P(BG) '''
            likelihood_sum += term_freq * np.logaddexp(np.log(word_Tsmm_prob[w_coord] * Tsmm_prob), np.log(word_bg_prob[w_coord] * bg_prob))
        print("Iteration #", iter_index+1, '=', likelihood_sum)
    # final
    return word_Tsmm_prob

# %% [markdown]
# # Query Model and Document Model Function

# %%
''' Query Unigram Model '''
@jit(nopython=True)
def query_modling(vocab, unigram_prob, Psmm_prob, alpha, beta, bg_prob):
    query_model = np.zeros((vocab))
    ''' [ alpha * PULM(w) + beta * Psmm(w) + (1-alpha-beta) * PBG(w) ] '''
    for i in range(vocab):
        query_model[i] = alpha * unigram_prob[i] + beta * Psmm_prob[i] + (1-alpha-beta) * bg_prob[i]
    return query_model

# %% [markdown]
# # KL-Divergence Function

# %%
# Probabilistic KL-Divergence
@jit(nopython=True)
def KL_Divergence(vocab, j, query_model, word_doc_prob, background_prob):
    prob = 0
    for i in range(vocab):
        ''' -Σ(wi->V) Psmm(w|q)* logP(w|dj) ''' 
        prob += query_model[i] * np.log(word_doc_prob[i, j])
    return -prob

@jit(nopython=True)
def KL_Divergence_by_unigram(vocab, j, query_model, word_doc_prob, background_prob, gamma):
    prob = 0
    for i in range(vocab):
        ''' -Σ(wi->V) Psmm(w|q)* logP(w|dj) ''' 
        # prob += query_model[i] * np.log(word_doc_prob[i, j])
        prob += query_model[i] * np.log(gamma * word_doc_prob[i, j] + (1-gamma)*background_prob[i])                                                               
    return -prob

def rank(query_doc_prob, map_at, rev=False):
    return [ (key, value) for key, value in sorted(query_doc_prob.items(),
              key = lambda item:item[1], reverse=rev)[:map_at] ]

# %% [markdown]
# # Loading Data

# %%
# main function
if __name__ == '__main__':
    
    start_time = now_time()    
    # Load Data
    print('load data ...')    
    doc_list = get_file_list('ntust-ir-2020_hw5_new/doc_list.txt')
    query_list = get_file_list('ntust-ir-2020_hw5_new/query_list.txt')
    documents = load_data(doc_list, 'ntust-ir-2020_hw5_new/docs/')
    queries = load_data(query_list, 'ntust-ir-2020_hw5_new/queries/')  
    print('load data finish！\n')
    cost_time(start_time, now_time())
# Out:
# load data ...
# load data finish！
#
# Cost time: 0:00:19.160419

# %% [markdown]
# # Data Preprocessing

# %%
    start_time = now_time()    
    # tokenization
    print('data preprocessing ...') 
    documents = [ cut(doc) for doc in documents ]
    queries = [ cut(query) for query in queries ]
    vocab_list = list(pd.read_csv('plsa_vocab', dtype=str).vocab)
    # get index term and collection
    corpus = Corpus()
    vocab_index, docs_index =  corpus.indexing(vocab_list, doc_list)
    print('data preprocessing finish！\n')
    cost_time(start_time, now_time())
# Out:
# data preprocessing ...
# data preprocessing finish！
#
# Cost time: 0:00:01.430626

# %% [markdown]
# # Document Model

# %%
    start_time = now_time()   
    # Load PLSA Document Model
    print('loading PLSA document model ...')
    plsa_prob = np.load('plsa_prob.npy')
    # plsa_prob = np.load('plsa_document_model.npy')
    print('loading PLSA document model finish！\n')
    cost_time(start_time, now_time())
# Out:
# loading PLSA document model ...
# loading PLSA document model finish！
#
# Cost time: 0:05:32.590588

# %% [markdown]
# # Background Model

# %%
    # background modeling  
    print('background modeling ...')
    bg_prob = np.load('plsa_background_model.npy')    
    print('background modeling finish！\n')
# Out:
# background modeling ...
# background modeling finish！

# %% [markdown]
# # Query Model

# %% [markdown]
# ### Query Unigram Model

# %%
    query_unigram_model = dict()
    for i in range(len(query_list)):
        unigram_prob = UnigramLanguageModel(vocab_index, queries[i])
        unigram_prob.modeling()
        query_unigram_model[query_list[i]] = unigram_prob.get_unigram_prob()

# %% [markdown]
# ### Select Pseudo Relevant Docs

# %%
    start_time = now_time()    
    # select pseudo relevant
    print('load pseudo relevant docs ...')    
    pseudo_list = load_pseudo_relevant_docs('PLSA_model.csv', top_ranked=4)
    print('load pseudo relevant docs finish！\n')
    print(pseudo_list)
# Out:
# load pseudo relevant docs ...
# load pseudo relevant docs finish！
#
# {301: ['FBIS4-41684', 'FBIS4-26397', 'FBIS4-45564', 'FBIS3-19199'], 302: ['LA043090-0036', 'FBIS4-67720', 'FBIS4-67701', 'FBIS3-41672'], 303: ['LA041990-0151', 'FT921-7107', 'FT941-15661', 'LA122990-0029'], 304: ['LA051890-0005', 'FR940713-1-00064', 'FR940616-0-00132', 'FR940816-1-00069'], 305: ['LA112489-0003', 'LA031689-0177', 'FT944-9883', 'FBIS3-59951'], 306: ['LA021790-0114', 'LA123190-0062', 'FBIS3-44115', 'FT942-9707'], 307: ['FBIS4-21356', 'FBIS3-6545', 'FBIS3-20665', 'FBIS4-33116'], 308: ['LA070489-0051', 'FR940214-1-00036', 'FR941027-2-00067', 'LA011590-0099'], 309: ['LA082490-0024', 'LA091089-0074', 'LA040189-0066', 'LA041990-0241'], 310: ['FT931-11958', 'LA100889-0041', 'FT934-14064', 'LA101089-0095'], 311: ['FT944-15440', 'FBIS3-58751', 'LA081789-0098', 'FT944-8837'], 312: ['LA051090-0097', 'LA040289-0050', 'LA052490-0029', 'FBIS4-67023'], 313: ['FBIS3-59655', 'FBIS4-66412', 'LA102690-0187', 'FT944-3015'], 314: ['LA100489-0072', 'LA122589-0092', 'LA042690-0006', 'LA050690-0009'], 315: ['LA112189-0058', 'LA021789-0154', 'LA021189-0138', 'LA112390-0037'], 316: ['FT932-4228', 'FT921-15729', 'FT924-4337', 'FT943-1071'], 317: ['LA052489-0152', 'LA051789-0061', 'LA073190-0082', 'LA080889-0065'], 318: ['FT921-14817', 'LA111990-0124', 'FBIS4-47834', 'FBIS4-56649'], 319: ['FBIS4-67889', 'FBIS3-28321', 'FBIS3-42072', 'FBIS4-66452'], 320: ['FBIS3-59596', 'LA031590-0184', 'LA102990-0070', 'FT922-7917'], 321: ['FT933-17002', 'FT921-610', 'LA121690-0044', 'FT934-11863'], 322: ['LA122789-0116', 'FT923-12234', 'FT944-8297', 'LA072689-0022'], 323: ['LA040489-0107', 'FT921-12564', 'LA010790-0054', 'LA102689-0011'], 324: ['FBIS3-10552', 'FT932-17486', 'LA080289-0074', 'FBIS3-10753'], 325: ['LA051390-0219', 'LA121590-0012', 'LA121390-0028', 'FT943-12085'], 326: ['FT944-15661', 'FT944-15057', 'FT944-10102', 'FT944-5084'], 327: ['LA100590-0008', 'FT934-15250', 'FT934-15708', 'LA062190-0015'], 328: ['FT942-10572', 'LA050189-0046', 'FT922-7713', 'LA050389-0062'], 329: ['LA061990-0058', 'LA061790-0069', 'FT921-15373', 'FT921-15471'], 330: ['FBIS4-13152', 'FBIS4-26164', 'FBIS4-35549', 'LA070490-0026'], 331: ['FT924-16122', 'FT942-13529', 'FT931-266', 'FT933-7879'], 332: ['LA032290-0185', 'LA041789-0115', 'LA011689-0065', 'FT941-10094'], 333: ['FT924-5307', 'LA052190-0106', 'FT942-6645', 'FT943-677'], 334: ['FR940727-2-00005', 'FR940111-2-00009', 'FT943-5307', 'FR940404-0-00017'], 335: ['LA070190-0096', 'LA071490-0012', 'LA072290-0043', 'LA090390-0002'], 336: ['LA012589-0100', 'LA081689-0039', 'LA123090-0078', 'FBIS4-16530'], 337: ['FBIS3-22624', 'FBIS3-60427', 'FBIS3-22539', 'FBIS3-41710'], 338: ['FT941-11009', 'FT941-16918', 'FR941017-1-00007', 'LA041790-0018'], 339: ['LA072489-0041', 'FT933-3956', 'LA082090-0069', 'FT922-1565'], 340: ['FT941-6884', 'FBIS3-5669', 'LA100990-0079', 'FBIS3-5917'], 341: ['FT933-6584', 'LA021489-0071', 'LA021790-0109', 'FBIS4-1468'], 342: ['FBIS4-36856', 'FBIS4-36917', 'LA052289-0053', 'LA031589-0128'], 343: ['LA101590-0075', 'FT941-10378', 'LA080289-0004', 'FT924-8932'], 344: ['FT941-6854', 'FR941216-0-00064', 'LA112990-0222', 'FR940303-0-00024'], 345: ['FT922-12878', 'FT942-13859', 'FT943-12012', 'FT944-9537'], 346: ['FT921-4473', 'FT924-221', 'FT934-3966', 'FT932-14842'], 347: ['FT942-16221', 'LA051890-0005', 'FBIS4-45823', 'FBIS4-25068'], 348: ['LA100689-0117', 'LA070589-0081', 'LA061089-0052', 'FT922-4205'], 349: ['FBIS3-43032', 'LA080890-0068', 'FBIS3-42994', 'FR940405-1-00043'], 350: ['LA062390-0104', 'LA052290-0188', 'LA060690-0112', 'LA011389-0085'], 351: ['FT941-9999', 'FT922-15099', 'FT942-12805', 'FT934-4848'], 352: ['FT942-8510', 'LA120290-0163', 'FT934-11803', 'FT944-4064'], 353: ['FT911-558', 'FT911-4348', 'LA111690-0059', 'LA120389-0149'], 354: ['FT932-451', 'FBIS4-66693', 'FBIS4-2431', 'FT934-3157'], 355: ['FBIS4-20436', 'FBIS4-49691', 'FBIS4-20917', 'FBIS4-44693'], 356: ['LA020589-0078', 'LA092890-0067', 'FT942-7603', 'LA033089-0013'], 357: ['FT932-10353', 'FT941-2301', 'FT923-4500', 'FT921-6 ...

# %%
    print('pseudo relevance docs preprocess ...')
    pseudo_query = dict()
    for query_id in pseudo_list:
        # for each query's pseudo relevant document's ID
        pseudo_doc_index_list = [ docs_index[doc_id] for doc_id in pseudo_list[query_id] ]  
        # ex: FBIS4-41684 FBIS3-23986 FBIS3-19646
        # term-pseudo_doc sparse matrix
        row = list()
        col = list()
        term_freq = list()
        
        for doc_index in pseudo_doc_index_list:
            tf = np.zeros(len(vocab_index))
            # calculate tf(i)
            for word in documents[doc_index]:
                tf[vocab_index[str(word)]] += 1
            # store sparse
            for word_index in tf.nonzero()[0]:
                row.append(word_index)
                col.append(doc_index)
                term_freq.append(tf[vocab_index[word]])
                
        sparse_term_pseudo_doc = sparse.coo_matrix((term_freq, (np.array(row), np.array(col))))
        # pseudo relevant document's info
        # put into for each query
        pseudo_query[query_id] = sparse_term_pseudo_doc
    print('pseudo relevance docs preprocess！\n')
    cost_time(start_time, now_time())
# Out:
# pseudo relevance docs preprocess ...
# pseudo relevance docs preprocess！
#
# Cost time: 0:00:09.594654

# %% [markdown]
# ### Query Simple Mixture Model

# %%
    start_time = now_time()    

    print('SMM training ...')
    smm_model = dict()

    for query_id in pseudo_query:
        
        # dimensional length
        word_size = len(vocab_index)
        # random initial (for each query)
        word_Tsmm_prob = random_initial(word_size)
        # print('for each query Tsmm:', word_Tsmm_prob.sum(axis=0))

        # print(sparse_term_doc)        
        # Psmm(wi)
        smm_model[str(query_id)] = smm(word_Tsmm_prob, bg_prob, 
                                       pseudo_query[query_id].row, 
                                       pseudo_query[query_id].col, 
                                       pseudo_query[query_id].data, 
                                       alpha=0.1, iter_num=30)
        print()
    print('SMM training finish！\n')
    cost_time(start_time, now_time())
# Out:
# SMM training ...
# Iteration Start:
# Iteration # 1 = -11051.805216494147
# Iteration # 2 = -9840.696318987935
# Iteration # 3 = -9813.020376381437
# Iteration # 4 = -9812.152154142412
# Iteration # 5 = -9811.869598421597
# Iteration # 6 = -9811.713157777955
# Iteration # 7 = -9811.630718103133
# Iteration # 8 = -9811.579188069825
# Iteration # 9 = -9811.55207576207
# Iteration # 10 = -9811.541524463883
# Iteration # 11 = -9811.538220287226
# Iteration # 12 = -9811.537264849674
# Iteration # 13 = -9811.536974749926
# Iteration # 14 = -9811.536874359112
# Iteration # 15 = -9811.536834398783
# Iteration # 16 = -9811.536816844533
# Iteration # 17 = -9811.536808712628
# Iteration # 18 = -9811.536804853553
# Iteration # 19 = -9811.536803004386
# Iteration # 20 = -9811.53680211537
# Iteration # 21 = -9811.536801687618
# Iteration # 22 = -9811.536801481827
# Iteration # 23 = -9811.536801382867
# Iteration # 24 = -9811.536801335284
# Iteration # 25 = -9811.536801312433
# Iteration # 26 = -9811.536801301447
# Iteration # 27 = -9811.536801296166
# Iteration # 28 = -9811.536801293641
# Iteration # 29 = -9811.53680129241
# Iteration # 30 = -9811.536801291835
#
# Iteration Start:
# Iteration # 1 = -4619.322099446413
# Iteration # 2 = -4232.983166957981
# Iteration # 3 = -4209.537171027648
# Iteration # 4 = -4206.963255628525
# Iteration # 5 = -4206.828596990154
# Iteration # 6 = -4206.82203804873
# Iteration # 7 = -4206.821725531148
# Iteration # 8 = -4206.821710758813
# Iteration # 9 = -4206.821710051919
# Iteration # 10 = -4206.821710017643
# Iteration # 11 = -4206.821710015965
# Iteration # 12 = -4206.821710015881
# Iteration # 13 = -4206.821710015873
# Iteration # 14 = -4206.821710015875
# Iteration # 15 = -4206.821710015872
# Iteration # 16 = -4206.821710015871
# Iteration # 17 = -4206.821710015876
# Iteration # 18 = -4206.821710015894
# Iteration # 19 = -4206.821710015877
# Iteration # 20 = -4206.821710015857
# Iteration # 21 = -4206.821710015847
# Iteration # 22 = -4206.821710015844
# Iteration # 23 = -4206.821710015842
# Iteration # 24 = -4206.821710015841
# Iteration # 25 = -4206.821710015841
# Iteration # 26 = -4206.821710015841
# Iteration # 27 = -4206.821710015841
# Iteration # 28 = -4206.821710015841
# Iteration # 29 = -4206.821710015841
# Iteration # 30 = -4206.821710015841
#
# Iteration Start:
# Iteration # 1 = -8148.051186992957
# Iteration # 2 = -7517.660345162384
# Iteration # 3 = -7486.05415582794
# Iteration # 4 = -7483.960446832854
# Iteration # 5 = -7483.565264052949
# Iteration # 6 = -7483.306554361841
# Iteration # 7 = -7483.1832459257585
# Iteration # 8 = -7483.160700981392
# Iteration # 9 = -7483.158576123023
# Iteration # 10 = -7483.158422842671
# Iteration # 11 = -7483.158412629484
# Iteration # 12 = -7483.158411962625
# Iteration # 13 = -7483.15841191925
# Iteration # 14 = -7483.158411916429
# Iteration # 15 = -7483.15841191623
# Iteration # 16 = -7483.158411916218
# Iteration # 17 = -7483.158411916217
# Iteration # 18 = -7483.158411916225
# Iteration # 19 = -7483.158411916215
# Iteration # 20 = -7483.158411916212
# Iteration # 21 = -7483.1584119162
# Iteration # 22 = -7483.158411916206
# Iteration # 23 = -7483.158411916224
# Iteration # 24 = -7483.158411916215
# Iteration # 25 = -7483.158411916263
# Iteration # 26 = -7483.158411916243
# Iteration # 27 = -7483.158411916241
# Iteration # 28 = -7483.15841191624
# Iteration # 29 = -7483.158411916238
# Iteration # 30 = -7483.158411916238
#
# Iteration Start:
# Iteration # 1 = -3919.357957695035
# Iteration # 2 = -3509.445708650973
# Iteration # 3 = -3493.0629256705697
# Iteration # 4 = -3492.4043398873837
# Iteration # 5 = -3492.3699292144906
# Iteration # 6 = -3492.3687430151062
# Iteration # 7 = -3492.3687015168703
# Iteration # 8 = -3492.3686997500945
# Iteration # 9 = -3492.368699661872
# Iteration # 10 = -3492.368699657059
# Iteration # 11 = -3492.368699656783
# Iteration # 12 = -3492.3686996567685
# Iteration # 13 = -3492.3686996567685
# Iteration # 14 = -3492.3686996567685
# Iteration # 15 = -3492.368699656764
# Iteration # 16 = -3492.3686996567644
# Iteration # 17 = -3492.368699656769
# Iteration # 18 = -3492.368699656766
# Iteration # 19 = -3492.3686996567603
# Iteration # 20 = -3492.3686996567753
# Iteration # 21 = -3492.3686996567694
# Iteration # 22 = -3492.3686996567667
# Iteration # 23 = -3492.3686996567667
# Iteration # 24 = -3492.3686996567667
# Iteration # 25 = -3492.3686996567667
# Iteration # 26 = -3492.3686996567667
# Iteration # 27 = -3492.3686996567667
# Iteration # 28 = -3492.3686996567667
# Iteration # 29 = -3492.3686996567667
# Iteration # 30 = -3492.3686996567667
#
# Iteration Start:
# Iteration # 1 = -3773.839021224778
# Iteration # 2 = -3487.857325520538
# Iteration # 3 = -3467.6937563352085
# Iteration # 4 = -3465.9250033498806
# Iteration # 5 = -3465.764624134379
# Iteration # 6 = -3465.7539153712933
# Iteration # 7 = -3465.753322705361
# Iteration # 8 = -3465.753287850853
# Iteration # 9 = -3465.7532854510114
# Iteration # 10 = -3465.7532852593004
# Iteration # 11 = -3465.7532852424015
# Iteration # 12 = -3465.753285240836
# Iteration # 13 = -3465.7532852406894
# Iteration # 14 = -3465.753285240668
# Iteration # 15 = -3465.7532852406716
# Iteration # 16 = -3465.753285240672
# Iteration # 17 = -3465.7532852406766
# Iteration # 18 = -3465.753285240662
# Iteration # 19 = -3465.753285240672
# Iteration # 20 = -3465.7532852406785
# Iteration # 21 = -3465.753285240666
# Iteration # 22 = -3465.7532852406503
# Iteration # 23 = -3465.753285240687
# Iteration # 24 = -3465.753285240685
# Iteration # 25 = -3465.753285240685
# Iteration # 26 = -3465.7532852406816
# Iteration # 27 = -3465.7532852406807
# Iteration # 28 = -3465.7532852406803
# Iteration # 29 = -3465.7532852406803
# Iteration # 30 = -3465.7532852406803
#
# Iteration Start:
# Iteration # 1 = -1494.2523554004329
# Iteration # 2 = -1364.5244955040896
# Iteration # 3 = -1355.4613190729947
# Iteration # 4 = -1353.7591655453887
# Iteration # 5 = -1353.730945452593
# Iteration # 6 = -1353.730728992282
# Iteration # 7 = -1353.7307259815555
# Iteration # 8 = -1353.7307259257038
# Iteration # 9 = -1353.730725924602
# Iteration # 10 = -1353.7307259245795
# Iteration # 11 = -1353.7307259245792
# Iteration # 12 = -1353.7307259245783
# Iteration # 13 = -1353.7307259245786
# Iteration # 14 = -1353.730725924578
# Iteration # 15 = -1353.73072592458
# Iteration # 16 = -1353.7307259245772
# Iteration # 17 = -1353.7307259245752
# Iteration # 18 = -1353.7307259245745
# Iteration # 19 = -1353.7307259245742
# Iteration # 20 = -1353.7307259245742
# Iteration # 21 = -1353.7307259245742
# Iteration # 22 = -1353.7307259245742
# Iteration # 23 = -1353.7307259245742
# Iteration # 24 = -1353.7307259245742
# Iteration # 25 = -1353.7307259245742
# Iteration # 26 = -1353.7307259245742
# Iteration # 27 = -1353.7307259245742
# Iteration # 28 = -1353.7307259245742
# Iteration # 29 = -1353.7307259245742
# Iteration # 30 = -1353.7307259245742
#
# Iteration Start:
# Iteration # 1 = -5038.526176525842
# Iteration # 2 = -4507.554867902736
# Iteration # 3 = -4475.732943576297
# Iteration # 4 = -4474.557412970979
# Iteration # 5 = -4474.520890242874
# Iteration # 6 = -4474.51947254543
# Iteration # 7 = -4474.519420250554
# Iteration # 8 = -4474.519418291163
# Iteration # 9 = -4474.519418214326
# Iteration # 10 = -4474.519418211141
# Iteration # 11 = -4474.519418211004
# Iteration # 12 = -4474.519418211003
# Iteration # 13 = -4474.519418210998
# Iteration # 14 = -4474.519418210997
# Iteration # 15 = -4474.519418210999
# Iteration # 16 = -4474.519418211005
# Iteration # 17 = -4474.519418210994
# Iteration # 18 = -4474.519418210999
# Iteration # 19 = -4474.519418211
# Iteration # 20 = -4474.519418211
# Iteration # 21 = -4474.519418210997
# Iteration # 22 = -4474.519418211
# Iteration # 23 = -4474.519418211
# Iteration # 24 = -4474.519418211
# Iteration # 25 = -4474.519418211
# Iteration # 26 = -4474.519418211
# Iteration # 27 = -4474.519418211
# Iteration # 28 = -4474.519418211
# Iteration # 29 = -4474.519418211
# Iteration # 30 = -4474.519418211
#
# Iteration Start:
# Iteration # 1 = -32785.83318999521
# Iteration # 2 = -30708.47934011372
# Iteration # 3 = -30571.25467456502
# Iteration # 4 = -30555.371852569264
# Iteration # 5 = -30551.91262865513
# Iteration # 6 = -30551.575215172434
# Iteration # 7 = -30551.555884981182
# Iteration # 8 = -30551.55396882863
# Iteration # 9 = -30551.55368880087
# Iteration # 10 = -30551.55361917918
# Iteration # 11 = -30551.553582448578
# Iteration # 12 = -30551.553552715755
# Iteration # 13 = -30551.553525810577
# Iteration # 14 = -30551.55350096512
# Iteration # 15 = -30551.55347796956
# Iteration # 16 = -30551.55345670768
# Iteration # 17 = -30551.55343708001
# Iteration # 18 = -30551.553418990636
# Iteration # 19 = -30551.553402345755
# Iteration # 20 = -30551.553387053802
# Iteration # 21 = -30551.553373025847
# Iteration # 22 = -30551.55336017598
# Iteration # 23 = -30551.55334842158
# Iteration # 24 = -30551.553337683566
# Iteration # 25 = -30551.553327886628
# Iteration # 26 = -30551.553318959217
# Iteration # 27 = -30551.553310833715
# Iteration # 28 = -30551.553303446482
# Iteration # 29 = -30551.553296737708
# Iteration # 30 = -30551.553290651267
#
# Iteration Start:
# Iteration # 1 = -14253.811806883907
# Iteration # 2 = -13391.719610984075
# Iteration # 3 = -13322.288878081848
# Iteration # 4 = -13311.848410245224
# Iteration # 5 = -13309.324145018334
# Iteration # 6 = -13309.027607010285
# Iteration # 7 = -13308.98452361533
# Iteration # 8 = -13308.975190486299
# Iteration # 9 = -13308.971219536254
# Iteration # 10 = -13308.96923948834
# Iteration # 11 = -13308.968255268766
# Iteration # 12 = -13308.96776483409
# Iteration # 13 = -13308.967515798562
# Iteration # 14 = -13308.9673860356
# Iteration # 15 = -13308.96731673429
# Iteration # 16 = -13308.967278992945
# Iteration # 17 = -13308.9672581544
# Iteration # 18 = -13308.967246545728
# Iteration # 19 = -13308.96724004399
# Iteration # 20 = -13308.967236391472
# Iteration # 21 = -13308.967234336356
# Iteration # 22 = -13308.967233179206
# Iteration # 23 = -13308.967232527524
# Iteration # 24 = -13308.96723216051
# Iteration # 25 = -13308.967231953875
# Iteration # 26 = -13308.967231837574
# Iteration # 27 = -13308.967231772089
# Iteration # 28 = -13308.967231735265
# Iteration # 29 = -13308.967231714534
# Iteration # 30 = -13308.967231702867
#
# Iteration Start:
# Iteration # 1 = -31901.1649389542
# Iteration # 2 = -30305.84564416689
# Iteration # 3 = -30160.030946752144
# Iteration # 4 = -30140.915345435325
# Iteration # 5 = -30136.817269102594
# Iteration # 6 = -30136.216976690524
# Iteration # 7 = -30136.132232916178
# Iteration # 8 = -30136.109763522294
# Iteration # 9 = -30136.10135733237
# Iteration # 10 = -30136.09788523519
# Iteration # 11 = -30136.09633385736
# Iteration # 12 = -30136.09555373413
# Iteration # 13 = -30136.095096945915
# Iteration # 14 = -30136.094786606995
# Iteration # 15 = -30136.094550967584
# Iteration # 16 = -30136.09435947908
# Iteration # 17 = -30136.094198060757
# Iteration # 18 = -30136.09405942962
# Iteration # 19 = -30136.09393925552
# Iteration # 20 = -30136.093834594594
# Iteration # 21 = -30136.093743229325
# Iteration # 22 = -30136.093663374362
# Iteration # 23 = -30136.093593536298
# Iteration # 24 = -30136.09353243914
# Iteration # 25 = -30136.093478980103
# Iteration # 26 = -30136.09343220032
# Iteration # 27 = -30136.09339126289
# Iteration # 28 = -30136.09335543624
# Iteration # 29 = -30136.093324080015
# Iteration # 30 = -30136.093296634084
#
# Iteration Start:
# Iteration # 1 = -6431.72643915964
# Iteration # 2 = -5898.133198443314
# Iteration # 3 = -5861.020850056313
# Iteration # 4 = -5858.207505170154
# Iteration # 5 = -5857.9698181779
# Iteration # 6 = -5857.948116216525
# Iteration # 7 = -5857.946077742276
# Iteration # 8 = -5857.945906914537
# Iteration # 9 = -5857.945893293341
# Iteration # 10 = -5857.945892218019
# Iteration # 11 = -5857.945892132614
# Iteration # 12 = -5857.9458921257265
# Iteration # 13 = -5857.945892125158
# Iteration # 14 = -5857.945892125109
# Iteration # 15 = -5857.94589212511
# Iteration # 16 = -5857.945892125098
# Iteration # 17 = -5857.945892125106
# Iteration # 18 = -5857.945892125103
# Iteration # 19 = -5857.945892125111
# Iteration # 20 = -5857.945892125103
# Iteration # 21 = -5857.945892125117
# Iteration # 22 = -5857.945892125115
# Iteration # 23 = -5857.945892125106
# Iteration # 24 = -5857.94589212508
# Iteration # 25 = -5857.945892125066
# Iteration # 26 = -5857.945892125114
# Iteration # 27 = -5857.9458921251135
# Iteration # 28 = -5857.945892125113
# Iteration # 29 = -5857.945892125113
# Iteration # 30 = -5857.945892125112
#
# Iteration Start:
# Iteration # 1 = -6770.0145596390275
# Iteration # 2 = -6229.570723592555
# Iteration # 3 = -6201.523909804649
# Iteration # 4 = -6199.713803546078
# Iteration # 5 = -6199.625939240227
# Iteration # 6 = -6199.615422619532
# Iteration # 7 = -6199.613751686622
# Iteration # 8 = -6199.613503298561
# Iteration # 9 = -6199.613467887861
# Iteration # 10 = -6199.613462921347
# Iteration # 11 = -6199.613462228597
# Iteration # 12 = -6199.613462132123
# Iteration # 13 = -6199.613462118692
# Iteration # 14 = -6199.613462116815
# Iteration # 15 = -6199.613462116565
# Iteration # 16 = -6199.613462116523
# Iteration # 17 = -6199.613462116518
# Iteration # 18 = -6199.613462116515
# Iteration # 19 = -6199.613462116515
# Iteration # 20 = -6199.613462116514
# Iteration # 21 = -6199.613462116514
# Iteration # 22 = -6199.6134621165165
# Iteration # 23 = -6199.6134621165265
# Iteration # 24 = -6199.61346211651
# Iteration # 25 = -6199.61346211649
# Iteration # 26 = -6199.613462116541
# Iteration # 27 = -6199.613462116531
# Iteration # 28 = -6199.613462116496
# Iteration # 29 = -6199.613462116494
# Iteration # 30 = -6199.613462116489
#
# Iteration Start:
# Iteration # 1 = -24682.830928286676
# Iteration # 2 = -22995.110844423205
# Iteration # 3 = -22876.648571406713
# Iteration # 4 = -22856.443420921223
# Iteration # 5 = -22850.095587334526
# Iteration # 6 = -22848.845673322634
# Iteration # 7 = -22848.720523966083
# Iteration # 8 = -22848.693907834295
# Iteration # 9 = -22848.682363353324
# Iteration # 10 = -22848.675697036007
# Iteration # 11 = -22848.67149563586
# Iteration # 12 = -22848.668812376854
# Iteration # 13 = -22848.667114799704
# Iteration # 14 = -22848.666056666007
# Iteration # 15 = -22848.665406810676
# Iteration # 16 = -22848.6650128827
# Iteration # 17 = -22848.664776682443
# Iteration # 18 = -22848.664636297435
# Iteration # 19 = -22848.66455343689
# Iteration # 20 = -22848.66450479082
# Iteration # 21 = -22848.664476347247
# Iteration # 22 = -22848.664459766256
# Iteration # 23 = -22848.664450121516
# Iteration # 24 = -22848.664444519967
# Iteration # 25 = -22848.664441269902
# Iteration # 26 = -22848.664439385328
# Iteration # 27 = -22848.664438292853
# Iteration # 28 = -22848.66443765956
# Iteration # 29 = -22848.664437292377
# Iteration # 30 = -22848.664437079464
#
# Iteration Start:
# Iteration # 1 = -12640.691121338457
# Iteration # 2 = -11817.567190283413
# Iteration # 3 = -11755.149702582332
# Iteration # 4 = -11745.982955828636
# Iteration # 5 = -11744.598856878565
# Iteration # 6 = -11744.535096632284
# Iteration # 7 = -11744.532666250963
# Iteration # 8 = -11744.532517667367
# Iteration # 9 = -11744.532505847617
# Iteration # 10 = -11744.532504836221
# Iteration # 11 = -11744.53250474796
# Iteration # 12 = -11744.532504740211
# Iteration # 13 = -11744.532504739542
# Iteration # 14 = -11744.53250473948
# Iteration # 15 = -11744.53250473947
# Iteration # 16 = -11744.532504739467
# Iteration # 17 = -11744.532504739484
# Iteration # 18 = -11744.532504739478
# Iteration # 19 = -11744.532504739485
# Iteration # 20 = -11744.532504739453
# Iteration # 21 = -11744.532504739464
# Iteration # 22 = -11744.532504739529
# Iteration # 23 = -11744.532504739524
# Iteration # 24 = -11744.532504739458
# Iteration # 25 = -11744.53250473944
# Iteration # 26 = -11744.53250473943
# Iteration # 27 = -11744.532504739429
# Iteration # 28 = -11744.532504739429
# Iteration # 29 = -11744.532504739429
# Iteration # 30 = -11744.532504739429
#
# Iteration Start:
# Iteration # 1 = -2406.804333353771
# Iteration # 2 = -2197.4047547924506
# Iteration # 3 = -2190.867754493551
# Iteration # 4 = -2190.730182867605
# Iteration # 5 = -2190.727966289995
# Iteration # 6 = -2190.7279299835172
# Iteration # 7 = -2190.727929385417
# Iteration # 8 = -2190.7279293753636
# Iteration # 9 = -2190.7279293751894
# Iteration # 10 = -2190.7279293751862
# Iteration # 11 = -2190.727929375189
# Iteration # 12 = -2190.727929375187
# Iteration # 13 = -2190.727929375187
# Iteration # 14 = -2190.7279293751867
# Iteration # 15 = -2190.727929375192
# Iteration # 16 = -2190.7279293751944
# Iteration # 17 = -2190.727929375192
# Iteration # 18 = -2190.727929375192
# Iteration # 19 = -2190.727929375192
# Iteration # 20 = -2190.727929375192
# Iteration # 21 = -2190.727929375192
# Iteration # 22 = -2190.727929375192
# Iteration # 23 = -2190.727929375192
# Iteration # 24 = -2190.727929375192
# Iteration # 25 = -2190.727929375192
# Iteration # 26 = -2190.727929375192
# Iteration # 27 = -2190.727929375192
# Iteration # 28 = -2190.727929375192
# Iteration # 29 = -2190.727929375192
# Iteration # 30 = -2190.727929375192
#
# Iteration Start:
# Iteration # 1 = -4772.534948901455
# Iteration # 2 = -4432.796787600138
# Iteration # 3 = -4399.639395178527
# Iteration # 4 = -4396.287525391873
# Iteration # 5 = -4395.748653038671
# Iteration # 6 = -4395.698792387613
# Iteration # 7 = -4395.685979377165
# Iteration # 8 = -4395.682378635982
# Iteration # 9 = -4395.681511414957
# Iteration # 10 = -4395.681321203186
# Iteration # 11 = -4395.681281387007
# Iteration # 12 = -4395.681273233559
# Iteration # 13 = -4395.681271580651
# Iteration # 14 = -4395.681271247088
# Iteration # 15 = -4395.681271179915
# Iteration # 16 = -4395.6812711664
# Iteration # 17 = -4395.681271163682
# Iteration # 18 = -4395.681271163136
# Iteration # 19 = -4395.681271163024
# Iteration # 20 = -4395.681271163007
# Iteration # 21 = -4395.681271162998
# Iteration # 22 = -4395.681271162997
# Iteration # 23 = -4395.681271162989
# Iteration # 24 = -4395.681271162994
# Iteration # 25 = -4395.681271163
# Iteration # 26 = -4395.681271162995
# Iteration # 27 = -4395.681271162996
# Iteration # 28 = -4395.681271163011
# Iteration # 29 = -4395.681271163
# Iteration # 30 = -4395.681271163008
#
# Iteration Start:
# Iteration # 1 = -21886.7077695944
# Iteration # 2 = -20204.971296440122
# Iteration # 3 = -20089.558190456697
# Iteration # 4 = -20080.43260751144
# Iteration # 5 = -20079.766688115942
# Iteration # 6 = -20079.67807595684
# Iteration # 7 = -20079.667347353417
# Iteration # 8 = -20079.666163327096
# Iteration # 9 = -20079.66603450037
# Iteration # 10 = -20079.666020238725
# Iteration # 11 = -20079.666018616626
# Iteration # 12 = -20079.66601842671
# Iteration # 13 = -20079.66601840388
# Iteration # 14 = -20079.666018401073
# Iteration # 15 = -20079.666018400687
# Iteration # 16 = -20079.66601840069
# Iteration # 17 = -20079.66601840069
# Iteration # 18 = -20079.666018400647
# Iteration # 19 = -20079.666018400687
# Iteration # 20 = -20079.66601840064
# Iteration # 21 = -20079.666018400614
# Iteration # 22 = -20079.666018400792
# Iteration # 23 = -20079.66601840083
# Iteration # 24 = -20079.666018400894
# Iteration # 25 = -20079.66601840043
# Iteration # 26 = -20079.666018400534
# Iteration # 27 = -20079.666018400574
# Iteration # 28 = -20079.66601840053
# Iteration # 29 = -20079.666018400523
# Iteration # 30 = -20079.666018400516
#
# Iteration Start:
# Iteration # 1 = -4444.951503535302
# Iteration # 2 = -4029.480200859166
# Iteration # 3 = -3998.0348594644006
# Iteration # 4 = -3995.133654310663
# Iteration # 5 = -3995.0845231269523
# Iteration # 6 = -3995.0840707585717
# Iteration # 7 = -3995.084066334295
# Iteration # 8 = -3995.0840662870523
# Iteration # 9 = -3995.084066286523
# Iteration # 10 = -3995.0840662865144
# Iteration # 11 = -3995.084066286516
# Iteration # 12 = -3995.0840662865185
# Iteration # 13 = -3995.0840662865107
# Iteration # 14 = -3995.0840662865085
# Iteration # 15 = -3995.0840662865357
# Iteration # 16 = -3995.084066286535
# Iteration # 17 = -3995.0840662865376
# Iteration # 18 = -3995.0840662865376
# Iteration # 19 = -3995.0840662865376
# Iteration # 20 = -3995.0840662865376
# Iteration # 21 = -3995.0840662865376
# Iteration # 22 = -3995.0840662865376
# Iteration # 23 = -3995.0840662865376
# Iteration # 24 = -3995.0840662865376
# Iteration # 25 = -3995.0840662865376
# Iteration # 26 = -3995.0840662865376
# Iteration # 27 = -3995.0840662865376
# Iteration # 28 = -3995.0840662865376
# Iteration # 29 = -3995.0840662865376
# Iteration # 30 = -3995.0840662865376
#
# Iteration Start:
# Iteration # 1 = -21213.03754401089
# Iteration # 2 = -19185.26375316296
# Iteration # 3 = -19095.63006576893
# Iteration # 4 = -19093.218391801678
# Iteration # 5 = -19092.716953996012
# Iteration # 6 = -19092.48155932969
# Iteration # 7 = -19092.33715849715
# Iteration # 8 = -19092.24185872655
# Iteration # 9 = -19092.178503200066
# Iteration # 10 = -19092.136082231937
# Iteration # 11 = -19092.10825828821
# Iteration # 12 = -19092.091172328786
# Iteration # 13 = -19092.081606867432
# Iteration # 14 = -19092.076727079526
# Iteration # 15 = -19092.074424055834
# Iteration # 16 = -19092.07339831381
# Iteration # 17 = -19092.07295914217
# Iteration # 18 = -19092.072775695928
# Iteration # 19 = -19092.072700105597
# Iteration # 20 = -19092.07266912975
# Iteration # 21 = -19092.072656430242
# Iteration # 22 = -19092.072651197075
# Iteration # 23 = -19092.07264902151
# Iteration # 24 = -19092.072648106252
# Iteration # 25 = -19092.072647715584
# Iteration # 26 = -19092.072647546127
# Iteration # 27 = -19092.07264747123
# Iteration # 28 = -19092.072647437555
# Iteration # 29 = -19092.072647422152
# Iteration # 30 = -19092.07264741494
#
# Iteration Start:
# Iteration # 1 = -34051.72775236682
# Iteration # 2 = -31683.947106696538
# Iteration # 3 = -31535.4040090771
# Iteration # 4 = -31517.542340061154
# Iteration # 5 = -31512.218173004883
# Iteration # 6 = -31510.513100401567
# Iteration # 7 = -31510.251424306072
# Iteration # 8 = -31510.221445852443
# Iteration # 9 = -31510.217341746345
# Iteration # 10 = -31510.216602727007
# Iteration # 11 = -31510.216444978552
# Iteration # 12 = -31510.216408713688
# Iteration # 13 = -31510.2164001286
# Iteration # 14 = -31510.216398071367
# Iteration # 15 = -31510.21639757563
# Iteration # 16 = -31510.21639745585
# Iteration # 17 = -31510.216397426895
# Iteration # 18 = -31510.216397419823
# Iteration # 19 = -31510.21639741812
# Iteration # 20 = -31510.216397417735
# Iteration # 21 = -31510.21639741765
# Iteration # 22 = -31510.216397417596
# Iteration # 23 = -31510.2163974176
# Iteration # 24 = -31510.216397417593
# Iteration # 25 = -31510.216397417546
# Iteration # 26 = -31510.21639741759
# Iteration # 27 = -31510.21639741761
# Iteration # 28 = -31510.216397417556
# Iteration # 29 = -31510.21639741767
# Iteration # 30 = -31510.216397417513
#
# Iteration Start:
# Iteration # 1 = -13828.42240861911
# Iteration # 2 = -12761.313563266742
# Iteration # 3 = -12686.465699032486
# Iteration # 4 = -12676.699380878043
# Iteration # 5 = -12674.69869524215
# Iteration # 6 = -12674.549225258468
# Iteration # 7 = -12674.540463480826
# Iteration # 8 = -12674.539965848655
# Iteration # 9 = -12674.539934034246
# Iteration # 10 = -12674.539931127745
# Iteration # 11 = -12674.539930703697
# Iteration # 12 = -12674.53993062168
# Iteration # 13 = -12674.539930604147
# Iteration # 14 = -12674.539930600315
# Iteration # 15 = -12674.539930599458
# Iteration # 16 = -12674.539930599258
# Iteration # 17 = -12674.539930599229
# Iteration # 18 = -12674.539930599221
# Iteration # 19 = -12674.539930599205
# Iteration # 20 = -12674.539930599209
# Iteration # 21 = -12674.539930599209
# Iteration # 22 = -12674.53993059923
# Iteration # 23 = -12674.539930599221
# Iteration # 24 = -12674.539930599178
# Iteration # 25 = -12674.539930599189
# Iteration # 26 = -12674.53993059924
# Iteration # 27 = -12674.53993059924
# Iteration # 28 = -12674.539930599154
# Iteration # 29 = -12674.539930599178
# Iteration # 30 = -12674.539930599238
#
# Iteration Start:
# Iteration # 1 = -4727.706189562178
# Iteration # 2 = -4362.269409550965
# Iteration # 3 = -4339.715520685738
# Iteration # 4 = -4336.886377356687
# Iteration # 5 = -4336.14907324794
# Iteration # 6 = -4336.003421662799
# Iteration # 7 = -4335.989447853118
# Iteration # 8 = -4335.98859787673
# Iteration # 9 = -4335.988553016454
# Iteration # 10 = -4335.988550728766
# Iteration # 11 = -4335.988550612977
# Iteration # 12 = -4335.988550607132
# Iteration # 13 = -4335.988550606842
# Iteration # 14 = -4335.988550606821
# Iteration # 15 = -4335.988550606822
# Iteration # 16 = -4335.988550606821
# Iteration # 17 = -4335.988550606815
# Iteration # 18 = -4335.988550606825
# Iteration # 19 = -4335.988550606809
# Iteration # 20 = -4335.988550606838
# Iteration # 21 = -4335.988550606808
# Iteration # 22 = -4335.988550606785
# Iteration # 23 = -4335.988550606778
# Iteration # 24 = -4335.988550606776
# Iteration # 25 = -4335.988550606776
# Iteration # 26 = -4335.988550606775
# Iteration # 27 = -4335.988550606775
# Iteration # 28 = -4335.988550606775
# Iteration # 29 = -4335.988550606775
# Iteration # 30 = -4335.988550606775
#
# Iteration Start:
# Iteration # 1 = -19219.668678368333
# Iteration # 2 = -18186.820139195785
# Iteration # 3 = -18115.65435405961
# Iteration # 4 = -18107.942931411264
# Iteration # 5 = -18105.901678216407
# Iteration # 6 = -18105.529795847833
# Iteration # 7 = -18105.488556612236
# Iteration # 8 = -18105.481550640565
# Iteration # 9 = -18105.479552021585
# Iteration # 10 = -18105.478740796614
# Iteration # 11 = -18105.478321494167
# Iteration # 12 = -18105.47807525972
# Iteration # 13 = -18105.477923407143
# Iteration # 14 = -18105.47782853258
# Iteration # 15 = -18105.47776923013
# Iteration # 16 = -18105.477732261406
# Iteration # 17 = -18105.477709272465
# Iteration # 18 = -18105.477694995458
# Iteration # 19 = -18105.47768612867
# Iteration # 20 = -18105.47768061509
# Iteration # 21 = -18105.477677178867
# Iteration # 22 = -18105.477675030706
# Iteration # 23 = -18105.477673682803
# Iteration # 24 = -18105.477672833487
# Iteration # 25 = -18105.47767229589
# Iteration # 26 = -18105.477671954017
# Iteration # 27 = -18105.477671735585
# Iteration # 28 = -18105.477671595323
# Iteration # 29 = -18105.47767150485
# Iteration # 30 = -18105.477671446224
#
# Iteration Start:
# Iteration # 1 = -1887.4652838293894
# Iteration # 2 = -1693.2680640811634
# Iteration # 3 = -1681.6106696464542
# Iteration # 4 = -1679.8828694433162
# Iteration # 5 = -1679.845025423488
# Iteration # 6 = -1679.844846104374
# Iteration # 7 = -1679.844845281466
# Iteration # 8 = -1679.8448452764903
# Iteration # 9 = -1679.8448452764533
# Iteration # 10 = -1679.8448452764512
# Iteration # 11 = -1679.8448452764517
# Iteration # 12 = -1679.8448452764528
# Iteration # 13 = -1679.8448452764521
# Iteration # 14 = -1679.844845276455
# Iteration # 15 = -1679.84484527646
# Iteration # 16 = -1679.8448452764596
# Iteration # 17 = -1679.8448452764594
# Iteration # 18 = -1679.8448452764594
# Iteration # 19 = -1679.8448452764594
# Iteration # 20 = -1679.8448452764594
# Iteration # 21 = -1679.8448452764594
# Iteration # 22 = -1679.8448452764594
# Iteration # 23 = -1679.8448452764594
# Iteration # 24 = -1679.8448452764594
# Iteration # 25 = -1679.8448452764594
# Iteration # 26 = -1679.8448452764594
# Iteration # 27 = -1679.8448452764594
# Iteration # 28 = -1679.8448452764594
# Iteration # 29 = -1679.8448452764594
# Iteration # 30 = -1679.8448452764594
#
# Iteration Start:
# Iteration # 1 = -47877.32579429837
# Iteration # 2 = -45346.018505808
# Iteration # 3 = -45141.810560261925
# Iteration # 4 = -45117.99161788943
# Iteration # 5 = -45115.626798259116
# Iteration # 6 = -45115.272808305854
# Iteration # 7 = -45115.161854805614
# Iteration # 8 = -45115.10692762306
# Iteration # 9 = -45115.07875540734
# Iteration # 10 = -45115.065250221276
# Iteration # 11 = -45115.059111704395
# Iteration # 12 = -45115.05634469439
# Iteration # 13 = -45115.05503145878
# Iteration # 14 = -45115.05433165884
# Iteration # 15 = -45115.05389594895
# Iteration # 16 = -45115.05358209071
# Iteration # 17 = -45115.053331643045
# Iteration # 18 = -45115.05311953974
# Iteration # 19 = -45115.052934096224
# Iteration # 20 = -45115.05276916071
# Iteration # 21 = -45115.05262100977
# Iteration # 22 = -45115.05248709009
# Iteration # 23 = -45115.052365483425
# Iteration # 24 = -45115.05225466163
# Iteration # 25 = -45115.0521533642
# Iteration # 26 = -45115.05206052898
# Iteration # 27 = -45115.05197524824
# Iteration # 28 = -45115.05189673875
# Iteration # 29 = -45115.05182432031
# Iteration # 30 = -45115.051757398556
#
# Iteration Start:
# Iteration # 1 = -957.166185592752
# Iteration # 2 = -854.7821599674651
# Iteration # 3 = -853.1320916537492
# Iteration # 4 = -853.0851171781152
# Iteration # 5 = -853.0842492537951
# Iteration # 6 = -853.0842369438199
# Iteration # 7 = -853.0842367764369
# Iteration # 8 = -853.084236774172
# Iteration # 9 = -853.0842367741411
# Iteration # 10 = -853.0842367741402
# Iteration # 11 = -853.0842367741408
# Iteration # 12 = -853.0842367741405
# Iteration # 13 = -853.0842367741404
# Iteration # 14 = -853.084236774141
# Iteration # 15 = -853.0842367741423
# Iteration # 16 = -853.0842367741413
# Iteration # 17 = -853.0842367741411
# Iteration # 18 = -853.0842367741411
# Iteration # 19 = -853.0842367741411
# Iteration # 20 = -853.0842367741411
# Iteration # 21 = -853.0842367741411
# Iteration # 22 = -853.0842367741411
# Iteration # 23 = -853.0842367741411
# Iteration # 24 = -853.0842367741411
# Iteration # 25 = -853.0842367741411
# Iteration # 26 = -853.0842367741411
# Iteration # 27 = -853.0842367741411
# Iteration # 28 = -853.0842367741411
# Iteration # 29 = -853.0842367741411
# Iteration # 30 = -853.0842367741411
#
# Iteration Start:
# Iteration # 1 = -10518.17041411338
# Iteration # 2 = -9779.54557817312
# Iteration # 3 = -9728.32682182118
# Iteration # 4 = -9723.288656585552
# Iteration # 5 = -9721.484081900888
# Iteration # 6 = -9721.28495690408
# Iteration # 7 = -9721.269784507755
# Iteration # 8 = -9721.268419099375
# Iteration # 9 = -9721.268285471835
# Iteration # 10 = -9721.268270622155
# Iteration # 11 = -9721.268268666206
# Iteration # 12 = -9721.268268299498
# Iteration # 13 = -9721.26826815488
# Iteration # 14 = -9721.268268047894
# Iteration # 15 = -9721.26826795125
# Iteration # 16 = -9721.268267860449
# Iteration # 17 = -9721.268267774538
# Iteration # 18 = -9721.26826769318
# Iteration # 19 = -9721.268267616113
# Iteration # 20 = -9721.268267543133
# Iteration # 21 = -9721.268267474
# Iteration # 22 = -9721.268267408539
# Iteration # 23 = -9721.268267346579
# Iteration # 24 = -9721.268267287902
# Iteration # 25 = -9721.26826723238
# Iteration # 26 = -9721.268267179827
# Iteration # 27 = -9721.2682671301
# Iteration # 28 = -9721.268267083042
# Iteration # 29 = -9721.268267038531
# Iteration # 30 = -9721.268266996418
#
# Iteration Start:
# Iteration # 1 = -8484.877786452753
# Iteration # 2 = -8000.3432574988365
# Iteration # 3 = -7962.016230297169
# Iteration # 4 = -7957.366421656362
# Iteration # 5 = -7956.70245211768
# Iteration # 6 = -7956.525657899255
# Iteration # 7 = -7956.471582677437
# Iteration # 8 = -7956.458806974051
# Iteration # 9 = -7956.456267585848
# Iteration # 10 = -7956.455788537361
# Iteration # 11 = -7956.455697234992
# Iteration # 12 = -7956.455679282145
# Iteration # 13 = -7956.455675631976
# Iteration # 14 = -7956.455674867999
# Iteration # 15 = -7956.455674704388
# Iteration # 16 = -7956.4556746687385
# Iteration # 17 = -7956.455674660858
# Iteration # 18 = -7956.455674659113
# Iteration # 19 = -7956.455674658703
# Iteration # 20 = -7956.455674658628
# Iteration # 21 = -7956.455674658611
# Iteration # 22 = -7956.4556746585995
# Iteration # 23 = -7956.455674658601
# Iteration # 24 = -7956.455674658593
# Iteration # 25 = -7956.455674658618
# Iteration # 26 = -7956.4556746586095
# Iteration # 27 = -7956.455674658594
# Iteration # 28 = -7956.455674658612
# Iteration # 29 = -7956.45567465864
# Iteration # 30 = -7956.455674658484
#
# Iteration Start:
# Iteration # 1 = -2383.9139776561997
# Iteration # 2 = -2107.5793401215474
# Iteration # 3 = -2094.315177393136
# Iteration # 4 = -2094.1710247120827
# Iteration # 5 = -2093.99187970601
# Iteration # 6 = -2093.7209135126704
# Iteration # 7 = -2093.583158325221
# Iteration # 8 = -2093.5609653421966
# Iteration # 9 = -2093.559232916104
# Iteration # 10 = -2093.5591296255698
# Iteration # 11 = -2093.559123900744
# Iteration # 12 = -2093.559123589008
# Iteration # 13 = -2093.5591235721004
# Iteration # 14 = -2093.5591235711854
# Iteration # 15 = -2093.559123571136
# Iteration # 16 = -2093.5591235711363
# Iteration # 17 = -2093.5591235711336
# Iteration # 18 = -2093.559123571134
# Iteration # 19 = -2093.559123571133
# Iteration # 20 = -2093.559123571136
# Iteration # 21 = -2093.5591235711286
# Iteration # 22 = -2093.559123571125
# Iteration # 23 = -2093.5591235711395
# Iteration # 24 = -2093.5591235711313
# Iteration # 25 = -2093.559123571128
# Iteration # 26 = -2093.5591235711277
# Iteration # 27 = -2093.559123571127
# Iteration # 28 = -2093.559123571127
# Iteration # 29 = -2093.559123571127
# Iteration # 30 = -2093.559123571127
#
# Iteration Start:
# Iteration # 1 = -8129.908996156085
# Iteration # 2 = -7310.3983417339805
# Iteration # 3 = -7272.513711314395
# Iteration # 4 = -7271.386923171336
# Iteration # 5 = -7271.306932792552
# Iteration # 6 = -7271.295215087056
# Iteration # 7 = -7271.292994075299
# Iteration # 8 = -7271.292370806347
# Iteration # 9 = -7271.29204130154
# Iteration # 10 = -7271.291775683979
# Iteration # 11 = -7271.2915332491875
# Iteration # 12 = -7271.291307701365
# Iteration # 13 = -7271.29109892213
# Iteration # 14 = -7271.290907610985
# Iteration # 15 = -7271.290734234636
# Iteration # 16 = -7271.290578837879
# Iteration # 17 = -7271.290441047537
# Iteration # 18 = -7271.290320129821
# Iteration # 19 = -7271.2902150660775
# Iteration # 20 = -7271.29012463358
# Iteration # 21 = -7271.290047483658
# Iteration # 22 = -7271.289982212025
# Iteration # 23 = -7271.289927417771
# Iteration # 24 = -7271.2898817499745
# Iteration # 25 = -7271.289843941521
# Iteration # 26 = -7271.289812831157
# Iteration # 27 = -7271.28978737558
# Iteration # 28 = -7271.289766653376
# Iteration # 29 = -7271.289749862759
# Iteration # 30 = -7271.289736315085
#
# Iteration Start:
# Iteration # 1 = -2571.3573719798983
# Iteration # 2 = -2331.7063621762945
# Iteration # 3 = -2321.7361024299735
# Iteration # 4 = -2321.494552717777
# Iteration # 5 = -2321.4917194359728
# Iteration # 6 = -2321.4916868260525
# Iteration # 7 = -2321.4916863829208
# Iteration # 8 = -2321.4916863762273
# Iteration # 9 = -2321.49168637612
# Iteration # 10 = -2321.491686376122
# Iteration # 11 = -2321.491686376118
# Iteration # 12 = -2321.4916863761173
# Iteration # 13 = -2321.491686376118
# Iteration # 14 = -2321.4916863761237
# Iteration # 15 = -2321.491686376119
# Iteration # 16 = -2321.491686376119
# Iteration # 17 = -2321.4916863761173
# Iteration # 18 = -2321.4916863761173
# Iteration # 19 = -2321.4916863761173
# Iteration # 20 = -2321.4916863761173
# Iteration # 21 = -2321.4916863761173
# Iteration # 22 = -2321.4916863761173
# Iteration # 23 = -2321.4916863761173
# Iteration # 24 = -2321.4916863761173
# Iteration # 25 = -2321.4916863761173
# Iteration # 26 = -2321.4916863761173
# Iteration # 27 = -2321.4916863761173
# Iteration # 28 = -2321.4916863761173
# Iteration # 29 = -2321.4916863761173
# Iteration # 30 = -2321.4916863761173
#
# Iteration Start:
# Iteration # 1 = -2046.6185745696414
# Iteration # 2 = -1821.8667704582647
# Iteration # 3 = -1814.5091280526165
# Iteration # 4 = -1814.1066814902201
# Iteration # 5 = -1814.1023871394532
# Iteration # 6 = -1814.102360417927
# Iteration # 7 = -1814.1023602393777
# Iteration # 8 = -1814.1023602379482
# Iteration # 9 = -1814.1023602379337
# Iteration # 10 = -1814.102360237933
# Iteration # 11 = -1814.1023602379337
# Iteration # 12 = -1814.1023602379332
# Iteration # 13 = -1814.1023602379341
# Iteration # 14 = -1814.102360237935
# Iteration # 15 = -1814.1023602379307
# Iteration # 16 = -1814.102360237931
# Iteration # 17 = -1814.1023602379307
# Iteration # 18 = -1814.1023602379307
# Iteration # 19 = -1814.1023602379307
# Iteration # 20 = -1814.1023602379307
# Iteration # 21 = -1814.1023602379307
# Iteration # 22 = -1814.1023602379307
# Iteration # 23 = -1814.1023602379307
# Iteration # 24 = -1814.1023602379307
# Iteration # 25 = -1814.1023602379307
# Iteration # 26 = -1814.1023602379307
# Iteration # 27 = -1814.1023602379307
# Iteration # 28 = -1814.1023602379307
# Iteration # 29 = -1814.1023602379307
# Iteration # 30 = -1814.1023602379307
#
# Iteration Start:
# Iteration # 1 = -65654.5676739506
# Iteration # 2 = -61122.453688492235
# Iteration # 3 = -60835.209134879486
# Iteration # 4 = -60767.63198441548
# Iteration # 5 = -60757.298667071795
# Iteration # 6 = -60756.52326292144
# Iteration # 7 = -60756.271819217895
# Iteration # 8 = -60756.14263044495
# Iteration # 9 = -60756.0699159589
# Iteration # 10 = -60756.02737896833
# Iteration # 11 = -60756.001882043885
# Iteration # 12 = -60755.986101880444
# Iteration # 13 = -60755.975849501745
# Iteration # 14 = -60755.9687836034
# Iteration # 15 = -60755.96362934171
# Iteration # 16 = -60755.95969242135
# Iteration # 17 = -60755.95658181578
# Iteration # 18 = -60755.95406415315
# Iteration # 19 = -60755.95199060505
# Iteration # 20 = -60755.95026030901
# Iteration # 21 = -60755.94880148178
# Iteration # 22 = -60755.94756111073
# Iteration # 23 = -60755.94649894665
# Iteration # 24 = -60755.94558377571
# Iteration # 25 = -60755.9447909813
# Iteration # 26 = -60755.94410088022
# Iteration # 27 = -60755.94349755008
# Iteration # 28 = -60755.94296798267
# Iteration # 29 = -60755.942501458805
# Iteration # 30 = -60755.942089078475
#
# Iteration Start:
# Iteration # 1 = -28595.85308659162
# Iteration # 2 = -26464.810149699548
# Iteration # 3 = -26337.5302411303
# Iteration # 4 = -26317.822029845403
# Iteration # 5 = -26315.934992078546
# Iteration # 6 = -26315.53635317016
# Iteration # 7 = -26315.413435747083
# Iteration # 8 = -26315.379862237787
# Iteration # 9 = -26315.372298387807
# Iteration # 10 = -26315.37063473142
# Iteration # 11 = -26315.37012058914
# Iteration # 12 = -26315.369826626367
# Iteration # 13 = -26315.36958629321
# Iteration # 14 = -26315.369370646815
# Iteration # 15 = -26315.369174454725
# Iteration # 16 = -26315.368996375902
# Iteration # 17 = -26315.368835582827
# Iteration # 18 = -26315.36869121163
# Iteration # 19 = -26315.368562297743
# Iteration # 20 = -26315.36844779469
# Iteration # 21 = -26315.368346604868
# Iteration # 22 = -26315.368257609884
# Iteration # 23 = -26315.368179696252
# Iteration # 24 = -26315.368111777494
# Iteration # 25 = -26315.368052811576
# Iteration # 26 = -26315.36800181335
# Iteration # 27 = -26315.367957863746
# Iteration # 28 = -26315.367920114837
# Iteration # 29 = -26315.36788779308
# Iteration # 30 = -26315.36786019835
#
# Iteration Start:
# Iteration # 1 = -3771.868407972135
# Iteration # 2 = -3476.8309272583288
# Iteration # 3 = -3460.959839623753
# Iteration # 4 = -3459.622231044386
# Iteration # 5 = -3459.584619452823
# Iteration # 6 = -3459.584102012169
# Iteration # 7 = -3459.5840929911483
# Iteration # 8 = -3459.5840927595937
# Iteration # 9 = -3459.584092751815
# Iteration # 10 = -3459.5840927515173
# Iteration # 11 = -3459.584092751509
# Iteration # 12 = -3459.5840927515032
# Iteration # 13 = -3459.584092751507
# Iteration # 14 = -3459.5840927515064
# Iteration # 15 = -3459.584092751513
# Iteration # 16 = -3459.5840927514996
# Iteration # 17 = -3459.5840927515146
# Iteration # 18 = -3459.584092751493
# Iteration # 19 = -3459.584092751489
# Iteration # 20 = -3459.584092751486
# Iteration # 21 = -3459.584092751485
# Iteration # 22 = -3459.584092751484
# Iteration # 23 = -3459.584092751484
# Iteration # 24 = -3459.584092751484
# Iteration # 25 = -3459.584092751484
# Iteration # 26 = -3459.584092751484
# Iteration # 27 = -3459.584092751484
# Iteration # 28 = -3459.584092751484
# Iteration # 29 = -3459.584092751484
# Iteration # 30 = -3459.584092751484
#
# Iteration Start:
# Iteration # 1 = -23589.74842325396
# Iteration # 2 = -22241.675378691325
# Iteration # 3 = -22144.054942524344
# Iteration # 4 = -22125.718284857947
# Iteration # 5 = -22122.7857993829
# Iteration # 6 = -22122.567496198775
# Iteration # 7 = -22122.49304683378
# Iteration # 8 = -22122.435973459305
# Iteration # 9 = -22122.38739981936
# Iteration # 10 = -22122.35299605703
# Iteration # 11 = -22122.33468783216
# Iteration # 12 = -22122.327245448054
# Iteration # 13 = -22122.324739165986
# Iteration # 14 = -22122.323957132197
# Iteration # 15 = -22122.323693354563
# Iteration # 16 = -22122.323576122508
# Iteration # 17 = -22122.323501667226
# Iteration # 18 = -22122.32344205035
# Iteration # 19 = -22122.323389588862
# Iteration # 20 = -22122.323341919626
# Iteration # 21 = -22122.32329810659
# Iteration # 22 = -22122.32325762856
# Iteration # 23 = -22122.323220110375
# Iteration # 24 = -22122.323185246936
# Iteration # 25 = -22122.323152777313
# Iteration # 26 = -22122.3231224748
# Iteration # 27 = -22122.32309413994
# Iteration # 28 = -22122.323067597008
# Iteration # 29 = -22122.32304269011
# Iteration # 30 = -22122.32301928051
#
# Iteration Start:
# Iteration # 1 = -6058.153468249004
# Iteration # 2 = -5654.858861055398
# Iteration # 3 = -5624.9440910668045
# Iteration # 4 = -5622.073990993137
# Iteration # 5 = -5621.755171989573
# Iteration # 6 = -5621.723375034193
# Iteration # 7 = -5621.707034524797
# Iteration # 8 = -5621.697252975717
# Iteration # 9 = -5621.692390423553
# Iteration # 10 = -5621.690318574273
# Iteration # 11 = -5621.689526641192
# Iteration # 12 = -5621.68924455828
# Iteration # 13 = -5621.68914835434
# Iteration # 14 = -5621.68911638198
# Iteration # 15 = -5621.689105915369
# Iteration # 16 = -5621.68910251861
# Iteration # 17 = -5621.689101421709
# Iteration # 18 = -5621.689101068489
# Iteration # 19 = -5621.689100954938
# Iteration # 20 = -5621.689100918457
# Iteration # 21 = -5621.6891009067485
# Iteration # 22 = -5621.689100902999
# Iteration # 23 = -5621.689100901785
# Iteration # 24 = -5621.6891009013925
# Iteration # 25 = -5621.689100901278
# Iteration # 26 = -5621.689100901236
# Iteration # 27 = -5621.689100901224
# Iteration # 28 = -5621.689100901213
# Iteration # 29 = -5621.689100901219
# Iteration # 30 = -5621.689100901217
#
# Iteration Start:
# Iteration # 1 = -7276.1173546499795
# Iteration # 2 = -6689.160002173595
# Iteration # 3 = -6654.766645303827
# Iteration # 4 = -6651.302801580075
# Iteration # 5 = -6650.880649979494
# Iteration # 6 = -6650.826106264131
# Iteration # 7 = -6650.818640084472
# Iteration # 8 = -6650.817568960587
# Iteration # 9 = -6650.817409528111
# Iteration # 10 = -6650.817384549846
# Iteration # 11 = -6650.817380410051
# Iteration # 12 = -6650.817379687782
# Iteration # 13 = -6650.817379556443
# Iteration # 14 = -6650.81737953184
# Iteration # 15 = -6650.81737952713
# Iteration # 16 = -6650.817379526215
# Iteration # 17 = -6650.817379526033
# Iteration # 18 = -6650.817379526005
# Iteration # 19 = -6650.81737952599
# Iteration # 20 = -6650.817379525984
# Iteration # 21 = -6650.817379525985
# Iteration # 22 = -6650.81737952599
# Iteration # 23 = -6650.817379525985
# Iteration # 24 = -6650.817379525992
# Iteration # 25 = -6650.817379525978
# Iteration # 26 = -6650.817379525967
# Iteration # 27 = -6650.817379526001
# Iteration # 28 = -6650.81737952599
# Iteration # 29 = -6650.817379525957
# Iteration # 30 = -6650.8173795260245
#
# Iteration Start:
# Iteration # 1 = -6726.75692032299
# Iteration # 2 = -6089.7113059825515
# Iteration # 3 = -6047.542516274905
# Iteration # 4 = -6044.810731307601
# Iteration # 5 = -6044.742343597349
# Iteration # 6 = -6044.731194762224
# Iteration # 7 = -6044.729308277995
# Iteration # 8 = -6044.729035437163
# Iteration # 9 = -6044.728998643861
# Iteration # 10 = -6044.728993813575
# Iteration # 11 = -6044.728993185666
# Iteration # 12 = -6044.728993104331
# Iteration # 13 = -6044.728993093813
# Iteration # 14 = -6044.728993092447
# Iteration # 15 = -6044.728993092268
# Iteration # 16 = -6044.728993092253
# Iteration # 17 = -6044.7289930922525
# Iteration # 18 = -6044.728993092249
# Iteration # 19 = -6044.728993092239
# Iteration # 20 = -6044.728993092245
# Iteration # 21 = -6044.7289930922425
# Iteration # 22 = -6044.728993092251
# Iteration # 23 = -6044.728993092256
# Iteration # 24 = -6044.728993092229
# Iteration # 25 = -6044.728993092237
# Iteration # 26 = -6044.728993092269
# Iteration # 27 = -6044.728993092264
# Iteration # 28 = -6044.728993092253
# Iteration # 29 = -6044.728993092265
# Iteration # 30 = -6044.728993092264
#
# Iteration Start:
# Iteration # 1 = -2094.3602557448066
# Iteration # 2 = -1876.8080523079984
# Iteration # 3 = -1866.8681414873545
# Iteration # 4 = -1865.752153880212
# Iteration # 5 = -1865.7446902122633
# Iteration # 6 = -1865.744668022756
# Iteration # 7 = -1865.7446678432252
# Iteration # 8 = -1865.7446678411636
# Iteration # 9 = -1865.7446678411386
# Iteration # 10 = -1865.7446678411384
# Iteration # 11 = -1865.7446678411386
# Iteration # 12 = -1865.7446678411382
# Iteration # 13 = -1865.7446678411402
# Iteration # 14 = -1865.74466784113
# Iteration # 15 = -1865.744667841141
# Iteration # 16 = -1865.7446678411395
# Iteration # 17 = -1865.7446678411395
# Iteration # 18 = -1865.7446678411393
# Iteration # 19 = -1865.7446678411393
# Iteration # 20 = -1865.7446678411393
# Iteration # 21 = -1865.7446678411393
# Iteration # 22 = -1865.7446678411393
# Iteration # 23 = -1865.7446678411393
# Iteration # 24 = -1865.7446678411393
# Iteration # 25 = -1865.7446678411393
# Iteration # 26 = -1865.7446678411393
# Iteration # 27 = -1865.7446678411393
# Iteration # 28 = -1865.7446678411393
# Iteration # 29 = -1865.7446678411393
# Iteration # 30 = -1865.7446678411393
#
# Iteration Start:
# Iteration # 1 = -1905.8003314895518
# Iteration # 2 = -1670.9211969163205
# Iteration # 3 = -1651.8007142782462
# Iteration # 4 = -1650.760382740814
# Iteration # 5 = -1650.6047494401766
# Iteration # 6 = -1650.6013124398773
# Iteration # 7 = -1650.6012782883868
# Iteration # 8 = -1650.6012779836794
# Iteration # 9 = -1650.6012779809885
# Iteration # 10 = -1650.6012779809655
# Iteration # 11 = -1650.6012779809657
# Iteration # 12 = -1650.6012779809653
# Iteration # 13 = -1650.6012779809646
# Iteration # 14 = -1650.601277980967
# Iteration # 15 = -1650.601277980972
# Iteration # 16 = -1650.6012779809719
# Iteration # 17 = -1650.6012779809716
# Iteration # 18 = -1650.6012779809716
# Iteration # 19 = -1650.6012779809716
# Iteration # 20 = -1650.6012779809716
# Iteration # 21 = -1650.6012779809716
# Iteration # 22 = -1650.6012779809716
# Iteration # 23 = -1650.6012779809716
# Iteration # 24 = -1650.6012779809716
# Iteration # 25 = -1650.6012779809716
# Iteration # 26 = -1650.6012779809716
# Iteration # 27 = -1650.6012779809716
# Iteration # 28 = -1650.6012779809716
# Iteration # 29 = -1650.6012779809716
# Iteration # 30 = -1650.6012779809716
#
# Iteration Start:
# Iteration # 1 = -4919.969206112533
# Iteration # 2 = -4486.067352036582
# Iteration # 3 = -4462.471071541866
# Iteration # 4 = -4459.9048616475775
# Iteration # 5 = -4459.568719605877
# Iteration # 6 = -4459.551803333571
# Iteration # 7 = -4459.551311325741
# Iteration # 8 = -4459.551298492789
# Iteration # 9 = -4459.551298153772
# Iteration # 10 = -4459.551298144356
# Iteration # 11 = -4459.551298144073
# Iteration # 12 = -4459.551298144066
# Iteration # 13 = -4459.551298144062
# Iteration # 14 = -4459.551298144062
# Iteration # 15 = -4459.551298144066
# Iteration # 16 = -4459.551298144058
# Iteration # 17 = -4459.551298144071
# Iteration # 18 = -4459.551298144056
# Iteration # 19 = -4459.551298144059
# Iteration # 20 = -4459.551298144045
# Iteration # 21 = -4459.551298144088
# Iteration # 22 = -4459.551298144093
# Iteration # 23 = -4459.551298144093
# Iteration # 24 = -4459.551298144095
# Iteration # 25 = -4459.551298144095
# Iteration # 26 = -4459.551298144095
# Iteration # 27 = -4459.551298144095
# Iteration # 28 = -4459.551298144095
# Iteration # 29 = -4459.551298144095
# Iteration # 30 = -4459.551298144095
#
# Iteration Start:
# Iteration # 1 = -599.566388112407
# Iteration # 2 = -533.1981691810539
# Iteration # 3 = -532.4270129895795
# Iteration # 4 = -532.4263350446429
# Iteration # 5 = -532.4263347328556
# Iteration # 6 = -532.4263347326483
# Iteration # 7 = -532.426334732648
# Iteration # 8 = -532.4263347326481
# Iteration # 9 = -532.4263347326483
# Iteration # 10 = -532.426334732648
# Iteration # 11 = -532.4263347326474
# Iteration # 12 = -532.4263347326474
# Iteration # 13 = -532.4263347326475
# Iteration # 14 = -532.4263347326475
# Iteration # 15 = -532.4263347326475
# Iteration # 16 = -532.4263347326475
# Iteration # 17 = -532.4263347326475
# Iteration # 18 = -532.4263347326475
# Iteration # 19 = -532.4263347326475
# Iteration # 20 = -532.4263347326475
# Iteration # 21 = -532.4263347326475
# Iteration # 22 = -532.4263347326475
# Iteration # 23 = -532.4263347326475
# Iteration # 24 = -532.4263347326475
# Iteration # 25 = -532.4263347326475
# Iteration # 26 = -532.4263347326475
# Iteration # 27 = -532.4263347326475
# Iteration # 28 = -532.4263347326475
# Iteration # 29 = -532.4263347326475
# Iteration # 30 = -532.4263347326475
#
# Iteration Start:
# Iteration # 1 = -25788.634199562865
# Iteration # 2 = -24082.622923950425
# Iteration # 3 = -23973.05449200823
# Iteration # 4 = -23960.617193127044
# Iteration # 5 = -23958.365454312516
# Iteration # 6 = -23957.58987014346
# Iteration # 7 = -23957.309256922617
# Iteration # 8 = -23957.181784299435
# Iteration # 9 = -23957.130396659777
# Iteration # 10 = -23957.111767730188
# Iteration # 11 = -23957.1042464771
# Iteration # 12 = -23957.100344236642
# Iteration # 13 = -23957.097909495686
# Iteration # 14 = -23957.096292214945
# Iteration # 15 = -23957.0952134242
# Iteration # 16 = -23957.094498404706
# Iteration # 17 = -23957.09402309632
# Iteration # 18 = -23957.09370113258
# Iteration # 19 = -23957.093475362413
# Iteration # 20 = -23957.093309650503
# ...
# Iteration # 14 = -1397.9020044240488
# Iteration # 15 = -1397.9020044240492
# Iteration # 16 = -1397.9020044240492
# Iteration # 17 = -1397.9020044240492
# Iteration # 18 = -1397.9020044240492
# Iteration # 19 = -1397.9020044240492
# Iteration # 20 = -1397.9020044240492
# Iteration # 21 = -1397.9020044240492
# Iteration # 22 = -1397.9020044240492
# Iteration # 23 = -1397.9020044240492
# Iteration # 24 = -1397.9020044240492
# Iteration # 25 = -1397.9020044240492
# Iteration # 26 = -1397.9020044240492
# Iteration # 27 = -1397.9020044240492
# Iteration # 28 = -1397.9020044240492
# Iteration # 29 = -1397.9020044240492
# Iteration # 30 = -1397.9020044240492
#
# Iteration Start:
# Iteration # 1 = -9726.996318515143
# Iteration # 2 = -8811.677430770282
# Iteration # 3 = -8779.39153228441
# Iteration # 4 = -8778.386889585288
# Iteration # 5 = -8778.28358616877
# Iteration # 6 = -8778.237200831774
# Iteration # 7 = -8778.204738598499
# Iteration # 8 = -8778.176142997841
# Iteration # 9 = -8778.151499382917
# Iteration # 10 = -8778.133998427627
# Iteration # 11 = -8778.124152630271
# Iteration # 12 = -8778.119648505313
# Iteration # 13 = -8778.117885943891
# Iteration # 14 = -8778.117265114095
# Iteration # 15 = -8778.117060306493
# Iteration # 16 = -8778.116995309394
# Iteration # 17 = -8778.116975134939
# Iteration # 18 = -8778.116968950702
# Iteration # 19 = -8778.11696706812
# Iteration # 20 = -8778.116966497231
# Iteration # 21 = -8778.116966324467
# Iteration # 22 = -8778.116966272264
# Iteration # 23 = -8778.11696625649
# Iteration # 24 = -8778.116966251726
# Iteration # 25 = -8778.11696625029
# Iteration # 26 = -8778.116966249858
# Iteration # 27 = -8778.11696624972
# Iteration # 28 = -8778.116966249685
# Iteration # 29 = -8778.116966249672
# Iteration # 30 = -8778.116966249672
#
# Iteration Start:
# Iteration # 1 = -1541.3830231129148
# Iteration # 2 = -1331.8475136865616
# Iteration # 3 = -1323.4311576973068
# Iteration # 4 = -1323.2527473872026
# Iteration # 5 = -1323.2506485082843
# Iteration # 6 = -1323.2506259639142
# Iteration # 7 = -1323.2506257038049
# Iteration # 8 = -1323.250625700628
# Iteration # 9 = -1323.250625700588
# Iteration # 10 = -1323.2506257005873
# Iteration # 11 = -1323.2506257005869
# Iteration # 12 = -1323.2506257005875
# Iteration # 13 = -1323.2506257005878
# Iteration # 14 = -1323.2506257005834
# Iteration # 15 = -1323.2506257005884
# Iteration # 16 = -1323.2506257005907
# Iteration # 17 = -1323.2506257005905
# Iteration # 18 = -1323.2506257005905
# Iteration # 19 = -1323.2506257005905
# Iteration # 20 = -1323.2506257005905
# Iteration # 21 = -1323.2506257005905
# Iteration # 22 = -1323.2506257005905
# Iteration # 23 = -1323.2506257005905
# Iteration # 24 = -1323.2506257005905
# Iteration # 25 = -1323.2506257005905
# Iteration # 26 = -1323.2506257005905
# Iteration # 27 = -1323.2506257005905
# Iteration # 28 = -1323.2506257005905
# Iteration # 29 = -1323.2506257005905
# Iteration # 30 = -1323.2506257005905
#
# Iteration Start:
# Iteration # 1 = -7985.48359319666
# Iteration # 2 = -7414.686923316349
# Iteration # 3 = -7375.321185239342
# Iteration # 4 = -7369.546203019848
# Iteration # 5 = -7367.926438497503
# Iteration # 6 = -7367.743007169863
# Iteration # 7 = -7367.730655613441
# Iteration # 8 = -7367.729665467597
# Iteration # 9 = -7367.729570299098
# Iteration # 10 = -7367.729559857643
# Iteration # 11 = -7367.729558596072
# Iteration # 12 = -7367.729558433604
# Iteration # 13 = -7367.729558411842
# Iteration # 14 = -7367.729558408864
# Iteration # 15 = -7367.7295584084695
# Iteration # 16 = -7367.729558408411
# Iteration # 17 = -7367.729558408394
# Iteration # 18 = -7367.72955840839
# Iteration # 19 = -7367.729558408392
# Iteration # 20 = -7367.729558408396
# Iteration # 21 = -7367.729558408391
# Iteration # 22 = -7367.729558408394
# Iteration # 23 = -7367.729558408416
# Iteration # 24 = -7367.72955840839
# Iteration # 25 = -7367.729558408411
# Iteration # 26 = -7367.729558408422
# Iteration # 27 = -7367.729558408367
# Iteration # 28 = -7367.729558408319
# Iteration # 29 = -7367.729558408434
# Iteration # 30 = -7367.729558408482
#
# Iteration Start:
# Iteration # 1 = -4630.193911283585
# Iteration # 2 = -4148.469315734964
# Iteration # 3 = -4130.309284391489
# Iteration # 4 = -4129.195537508195
# Iteration # 5 = -4129.170766396287
# Iteration # 6 = -4129.170253696228
# Iteration # 7 = -4129.170233710119
# Iteration # 8 = -4129.17023245109
# Iteration # 9 = -4129.170232357202
# Iteration # 10 = -4129.170232349888
# Iteration # 11 = -4129.170232349312
# Iteration # 12 = -4129.170232349264
# Iteration # 13 = -4129.170232349261
# Iteration # 14 = -4129.170232349261
# Iteration # 15 = -4129.17023234926
# Iteration # 16 = -4129.170232349263
# Iteration # 17 = -4129.170232349257
# Iteration # 18 = -4129.17023234926
# Iteration # 19 = -4129.1702323492655
# Iteration # 20 = -4129.170232349272
# Iteration # 21 = -4129.170232349264
# Iteration # 22 = -4129.170232349271
# Iteration # 23 = -4129.1702323492655
# Iteration # 24 = -4129.170232349265
# Iteration # 25 = -4129.170232349264
# Iteration # 26 = -4129.170232349264
# Iteration # 27 = -4129.170232349264
# Iteration # 28 = -4129.170232349264
# Iteration # 29 = -4129.170232349264
# Iteration # 30 = -4129.170232349264
#
# Iteration Start:
# Iteration # 1 = -3289.003327005237
# Iteration # 2 = -2989.533032574145
# Iteration # 3 = -2970.0372561045515
# Iteration # 4 = -2969.2779087265867
# Iteration # 5 = -2969.267542518366
# Iteration # 6 = -2969.267416271774
# Iteration # 7 = -2969.2674142683154
# Iteration # 8 = -2969.2674142290507
# Iteration # 9 = -2969.2674142281858
# Iteration # 10 = -2969.26741422817
# Iteration # 11 = -2969.2674142281676
# Iteration # 12 = -2969.267414228167
# Iteration # 13 = -2969.2674142281694
# Iteration # 14 = -2969.267414228165
# Iteration # 15 = -2969.2674142281685
# Iteration # 16 = -2969.2674142281594
# Iteration # 17 = -2969.267414228152
# Iteration # 18 = -2969.26741422815
# Iteration # 19 = -2969.2674142281494
# Iteration # 20 = -2969.267414228149
# Iteration # 21 = -2969.2674142281485
# Iteration # 22 = -2969.2674142281485
# Iteration # 23 = -2969.2674142281485
# Iteration # 24 = -2969.2674142281485
# Iteration # 25 = -2969.2674142281485
# Iteration # 26 = -2969.2674142281485
# Iteration # 27 = -2969.2674142281485
# Iteration # 28 = -2969.2674142281485
# Iteration # 29 = -2969.2674142281485
# Iteration # 30 = -2969.2674142281485
#
# Iteration Start:
# Iteration # 1 = -5278.75062107129
# Iteration # 2 = -4903.227131284551
# Iteration # 3 = -4872.926131484358
# Iteration # 4 = -4870.461002196153
# Iteration # 5 = -4870.312794244853
# Iteration # 6 = -4870.255670897084
# Iteration # 7 = -4870.214724869185
# Iteration # 8 = -4870.190308099906
# Iteration # 9 = -4870.179465420415
# Iteration # 10 = -4870.175712392097
# Iteration # 11 = -4870.17461387756
# Iteration # 12 = -4870.174322414716
# Iteration # 13 = -4870.174249062732
# Iteration # 14 = -4870.174231095928
# Iteration # 15 = -4870.174226754329
# Iteration # 16 = -4870.174225712186
# Iteration # 17 = -4870.174225462833
# Iteration # 18 = -4870.174225403282
# Iteration # 19 = -4870.174225389055
# Iteration # 20 = -4870.174225385663
# Iteration # 21 = -4870.174225384855
# Iteration # 22 = -4870.174225384663
# Iteration # 23 = -4870.174225384615
# Iteration # 24 = -4870.174225384606
# Iteration # 25 = -4870.174225384606
# Iteration # 26 = -4870.174225384598
# Iteration # 27 = -4870.174225384599
# Iteration # 28 = -4870.174225384606
# Iteration # 29 = -4870.17422538459
# Iteration # 30 = -4870.174225384599
#
# Iteration Start:
# Iteration # 1 = -6647.164464920362
# Iteration # 2 = -6097.288953095032
# Iteration # 3 = -6066.959528515634
# Iteration # 4 = -6063.701217609375
# Iteration # 5 = -6063.498628980887
# Iteration # 6 = -6063.484785491639
# Iteration # 7 = -6063.483773170687
# Iteration # 8 = -6063.483688726158
# Iteration # 9 = -6063.48368093086
# Iteration # 10 = -6063.483680168074
# Iteration # 11 = -6063.483680091171
# Iteration # 12 = -6063.483680083301
# Iteration # 13 = -6063.483680082492
# Iteration # 14 = -6063.483680082394
# Iteration # 15 = -6063.483680082399
# Iteration # 16 = -6063.483680082401
# Iteration # 17 = -6063.483680082397
# Iteration # 18 = -6063.4836800824005
# Iteration # 19 = -6063.483680082392
# Iteration # 20 = -6063.483680082387
# Iteration # 21 = -6063.483680082427
# Iteration # 22 = -6063.483680082374
# Iteration # 23 = -6063.483680082398
# Iteration # 24 = -6063.483680082463
# Iteration # 25 = -6063.483680082455
# Iteration # 26 = -6063.483680082448
# Iteration # 27 = -6063.483680082451
# Iteration # 28 = -6063.483680082451
# Iteration # 29 = -6063.483680082451
# Iteration # 30 = -6063.4836800824505
#
# Iteration Start:
# Iteration # 1 = -5356.889182308756
# Iteration # 2 = -4989.710768435987
# Iteration # 3 = -4966.425831105311
# Iteration # 4 = -4963.4798422081
# Iteration # 5 = -4962.859268870721
# Iteration # 6 = -4962.764514086826
# Iteration # 7 = -4962.739444083022
# Iteration # 8 = -4962.732334856782
# Iteration # 9 = -4962.730591333186
# Iteration # 10 = -4962.730209070226
# Iteration # 11 = -4962.730130214075
# Iteration # 12 = -4962.730114419182
# Iteration # 13 = -4962.730111298105
# Iteration # 14 = -4962.730110685149
# Iteration # 15 = -4962.7301105651
# Iteration # 16 = -4962.73011054161
# Iteration # 17 = -4962.730110537027
# Iteration # 18 = -4962.730110536121
# Iteration # 19 = -4962.730110535951
# Iteration # 20 = -4962.730110535916
# Iteration # 21 = -4962.73011053591
# Iteration # 22 = -4962.730110535901
# Iteration # 23 = -4962.730110535903
# Iteration # 24 = -4962.730110535911
# Iteration # 25 = -4962.730110535915
# Iteration # 26 = -4962.730110535911
# Iteration # 27 = -4962.730110535899
# Iteration # 28 = -4962.730110535905
# Iteration # 29 = -4962.730110535894
# Iteration # 30 = -4962.730110535881
#
# Iteration Start:
# Iteration # 1 = -968.0884162988336
# Iteration # 2 = -863.899956923383
# Iteration # 3 = -861.4495338298468
# Iteration # 4 = -861.3723871822159
# Iteration # 5 = -861.3718671675548
# Iteration # 6 = -861.3718636865353
# Iteration # 7 = -861.3718636577381
# Iteration # 8 = -861.3718636574695
# Iteration # 9 = -861.3718636574665
# Iteration # 10 = -861.3718636574667
# Iteration # 11 = -861.3718636574664
# Iteration # 12 = -861.3718636574657
# Iteration # 13 = -861.3718636574664
# Iteration # 14 = -861.3718636574661
# Iteration # 15 = -861.3718636574648
# Iteration # 16 = -861.3718636574647
# Iteration # 17 = -861.3718636574647
# Iteration # 18 = -861.3718636574647
# Iteration # 19 = -861.3718636574647
# Iteration # 20 = -861.3718636574647
# Iteration # 21 = -861.3718636574647
# Iteration # 22 = -861.3718636574647
# Iteration # 23 = -861.3718636574647
# Iteration # 24 = -861.3718636574647
# Iteration # 25 = -861.3718636574647
# Iteration # 26 = -861.3718636574647
# Iteration # 27 = -861.3718636574647
# Iteration # 28 = -861.3718636574647
# Iteration # 29 = -861.3718636574647
# Iteration # 30 = -861.3718636574647
#
# Iteration Start:
# Iteration # 1 = -7495.757400074344
# Iteration # 2 = -6799.0576865740095
# Iteration # 3 = -6757.459710727223
# Iteration # 4 = -6755.007257011611
# Iteration # 5 = -6754.753074787165
# Iteration # 6 = -6754.716772466692
# Iteration # 7 = -6754.691611846741
# Iteration # 8 = -6754.659358235741
# Iteration # 9 = -6754.623887719551
# Iteration # 10 = -6754.594463569641
# Iteration # 11 = -6754.576610352755
# Iteration # 12 = -6754.568470644623
# Iteration # 13 = -6754.565492077968
# Iteration # 14 = -6754.564550539787
# Iteration # 15 = -6754.564277872145
# Iteration # 16 = -6754.564202676273
# Iteration # 17 = -6754.564182475244
# Iteration # 18 = -6754.564177122363
# Iteration # 19 = -6754.564175713984
# Iteration # 20 = -6754.564175344794
# Iteration # 21 = -6754.564175248186
# Iteration # 22 = -6754.564175222947
# Iteration # 23 = -6754.564175216343
# Iteration # 24 = -6754.564175214626
# Iteration # 25 = -6754.564175214183
# Iteration # 26 = -6754.564175214054
# Iteration # 27 = -6754.564175214024
# Iteration # 28 = -6754.564175214019
# Iteration # 29 = -6754.564175214011
# Iteration # 30 = -6754.564175214015
#
# Iteration Start:
# Iteration # 1 = -46861.47018352337
# Iteration # 2 = -43646.53788294861
# Iteration # 3 = -43380.80026264205
# Iteration # 4 = -43360.55308778268
# Iteration # 5 = -43357.02547202675
# Iteration # 6 = -43355.94689253677
# Iteration # 7 = -43355.49214524295
# Iteration # 8 = -43355.323801873245
# Iteration # 9 = -43355.268854537666
# Iteration # 10 = -43355.24526989152
# Iteration # 11 = -43355.22983953002
# Iteration # 12 = -43355.21707208039
# Iteration # 13 = -43355.20592631881
# Iteration # 14 = -43355.19655127626
# Iteration # 15 = -43355.18920199119
# Iteration # 16 = -43355.1838390249
# Iteration # 17 = -43355.18012979587
# Iteration # 18 = -43355.17762794747
# Iteration # 19 = -43355.1759320365
# Iteration # 20 = -43355.174750046775
# Iteration # 21 = -43355.17389428216
# Iteration # 22 = -43355.173251359556
# Iteration # 23 = -43355.17275358461
# Iteration # 24 = -43355.172359383534
# Iteration # 25 = -43355.17204185336
# Iteration # 26 = -43355.171782565194
# Iteration # 27 = -43355.17156829074
# Iteration # 28 = -43355.17138922882
# Iteration # 29 = -43355.17123798008
# Iteration # 30 = -43355.171108898605
#
# Iteration Start:
# Iteration # 1 = -12284.442908535655
# Iteration # 2 = -11340.289942913849
# Iteration # 3 = -11288.933482166907
# Iteration # 4 = -11282.039667151803
# Iteration # 5 = -11280.384700449284
# Iteration # 6 = -11280.016109276212
# Iteration # 7 = -11279.809650535422
# Iteration # 8 = -11279.72179626548
# Iteration # 9 = -11279.69809430583
# Iteration # 10 = -11279.693343913536
# Iteration # 11 = -11279.692525003116
# Iteration # 12 = -11279.692392913948
# Iteration # 13 = -11279.692372184369
# Iteration # 14 = -11279.692368966631
# Iteration # 15 = -11279.692368469341
# Iteration # 16 = -11279.692368392603
# Iteration # 17 = -11279.69236838078
# Iteration # 18 = -11279.692368378963
# Iteration # 19 = -11279.692368378659
# Iteration # 20 = -11279.69236837862
# Iteration # 21 = -11279.692368378623
# Iteration # 22 = -11279.692368378617
# Iteration # 23 = -11279.692368378619
# Iteration # 24 = -11279.692368378612
# Iteration # 25 = -11279.692368378628
# Iteration # 26 = -11279.692368378606
# Iteration # 27 = -11279.692368378623
# Iteration # 28 = -11279.692368378643
# Iteration # 29 = -11279.692368378608
# Iteration # 30 = -11279.692368378699
#
# Iteration Start:
# Iteration # 1 = -78239.31129650628
# Iteration # 2 = -73097.84226699187
# Iteration # 3 = -72803.18296715176
# Iteration # 4 = -72779.0993617784
# Iteration # 5 = -72772.22242675118
# Iteration # 6 = -72764.17674593607
# Iteration # 7 = -72758.97346315008
# Iteration # 8 = -72757.8017818606
# Iteration # 9 = -72757.65575465311
# Iteration # 10 = -72757.62304860575
# Iteration # 11 = -72757.60467182142
# Iteration # 12 = -72757.59145923311
# Iteration # 13 = -72757.5816113922
# Iteration # 14 = -72757.57423828679
# Iteration # 15 = -72757.56871730299
# Iteration # 16 = -72757.564570393
# Iteration # 17 = -72757.56142899302
# Iteration # 18 = -72757.55901698214
# Iteration # 19 = -72757.55713408491
# Iteration # 20 = -72757.55563835672
# Iteration # 21 = -72757.55443019595
# Iteration # 22 = -72757.55343954808
# Iteration # 23 = -72757.55261655219
# Iteration # 24 = -72757.55192508764
# Iteration # 25 = -72757.55133845726
# Iteration # 26 = -72757.55083653117
# Iteration # 27 = -72757.55040385197
# Iteration # 28 = -72757.55002835924
# Iteration # 29 = -72757.54970051399
# Iteration # 30 = -72757.5494126833
#
# Iteration Start:
# Iteration # 1 = -20878.91548950545
# Iteration # 2 = -18891.171442882056
# Iteration # 3 = -18775.052204684223
# Iteration # 4 = -18759.79030217786
# Iteration # 5 = -18758.361585000857
# Iteration # 6 = -18758.26542966541
# Iteration # 7 = -18758.219840029713
# Iteration # 8 = -18758.193322280607
# Iteration # 9 = -18758.180654236
# Iteration # 10 = -18758.175663397735
# Iteration # 11 = -18758.17382691136
# Iteration # 12 = -18758.173074662496
# Iteration # 13 = -18758.172682628865
# Iteration # 14 = -18758.17242712284
# Iteration # 15 = -18758.17223892434
# Iteration # 16 = -18758.17209323887
# Iteration # 17 = -18758.1719784038
# Iteration # 18 = -18758.171887276523
# Iteration # 19 = -18758.171814758694
# Iteration # 20 = -18758.171756967124
# Iteration # 21 = -18758.17171087039
# Iteration # 22 = -18758.171674078687
# Iteration # 23 = -18758.17164469968
# Iteration # 24 = -18758.17162123106
# Iteration # 25 = -18758.171602478258
# Iteration # 26 = -18758.171587490113
# Iteration # 27 = -18758.171575508608
# Iteration # 28 = -18758.171565929144
# Iteration # 29 = -18758.171558269245
# Iteration # 30 = -18758.17155214371
#
# SMM training finish！
#
# Cost time: 0:00:02.515891

# %% [markdown]
# ### Query Modeling

# %%
    query_model = dict()
    for query_id in query_list:
        unigram_prob = query_unigram_model[query_id]
        smm_prob = smm_model[query_id]
        vocab = len(list(vocab_index.values()))
        # weight unigram, smm, background
        query_model[str(query_id)] = query_modling(vocab, unigram_prob, smm_prob, 0.5, 0.4, bg_prob)

# %%
    print(KL_Divergence(len(list(vocab_index.values())), docs_index['FBIS4-41684'], query_model['301'], plsa_prob, bg_prob))
    print(KL_Divergence(len(list(vocab_index.values())), docs_index['FBIS4-26397'], query_model['301'], plsa_prob, bg_prob))
    print(KL_Divergence(len(list(vocab_index.values())), docs_index['FBIS4-45564'], query_model['301'], plsa_prob, bg_prob))
    print(KL_Divergence(len(list(vocab_index.values())), docs_index['FBIS3-19199'], query_model['301'], plsa_prob, bg_prob))
    print(KL_Divergence(len(list(vocab_index.values())), docs_index['FBIS3-19646'], query_model['301'], plsa_prob, bg_prob))
    print(KL_Divergence(len(list(vocab_index.values())), docs_index['FBIS3-21961'], query_model['301'], plsa_prob, bg_prob))
    print(KL_Divergence(len(list(vocab_index.values())), docs_index['FBIS4-46734'], query_model['301'], plsa_prob, bg_prob))
    print(KL_Divergence(len(list(vocab_index.values())), docs_index['FBIS3-23986'], query_model['301'], plsa_prob, bg_prob))
    print(KL_Divergence(len(list(vocab_index.values())), docs_index['FBIS4-62079'], query_model['301'], plsa_prob, bg_prob))
    print(KL_Divergence(len(list(vocab_index.values())), docs_index['FBIS4-43965'], query_model['301'], plsa_prob, bg_prob))
# Out:
# 6.533684558822817
# 5.61710878436304
# 5.617091183427182
# 6.598010382862521
# 6.684149190533936
# 6.684119688155167
# 6.895033047443415
# 6.820608615336265
# 6.933155121879054
# 6.720297673147918

# %%
    pseudo_doc_list = load_pseudo_relevant_docs('smm_model_v3.csv', top_ranked=5000)

# %% [markdown]
# # KL-Divergence P(q||dj)

# %%
    start_time = now_time()    
    
    print('KL-Divergence measure ...')
    rank_prob = dict()
    for i in range(len(query_list)):
        query_id = int(query_list[i])
        print('query:#', query_id)
        word_query_prob = query_model[query_list[i]]
        query_doc_prob = { doc_id:0 for doc_id in pseudo_doc_list[query_id] }
        for j in progressbar(range(len(pseudo_doc_list[query_id])), "KL-Divergence measure: ", 50):
            '''parameters:'''
            doc_id = pseudo_doc_list[query_id][j]
            prob = KL_Divergence(len(list(vocab_index.values())), docs_index[doc_id], word_query_prob, plsa_prob, bg_prob)
            query_doc_prob[doc_id] = prob
        rank_prob[query_list[i]] = rank(query_doc_prob, 5000, rev=False)
        print()
#         print(rank_prob[query_list[i]])
#         break
    print('KL-Divergence measure finish！\n')
    cost_time(start_time, now_time())
# Out:
# KL-Divergence measure ...
# query:# 301
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 302
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 303
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 304
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 305
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 306
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 307
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 308
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 309
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 310
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 311
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 312
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 313
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 314
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 315
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 316
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 317
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 318
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 319
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 320
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 321
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 322
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 323
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 324
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 325
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 326
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 327
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 328
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 329
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 330
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 331
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 332
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 333
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 334
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 335
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 336
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 337
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 338
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 339
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 340
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 341
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 342
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 343
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 344
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 345
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 346
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 347
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 348
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 349
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 350
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 351
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 352
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 353
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 354
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 355
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 356
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 357
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 358
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 359
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 360
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 361
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 362
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 363
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 364
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 365
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 366
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 367
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 368
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 369
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 370
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 371
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 372
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 373
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 374
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 375
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 376
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 377
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 378
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 379
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 380
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 381
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 382
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 383
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 384
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 385
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 386
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 387
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 388
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 389
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 390
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 391
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 392
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 393
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 394
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 395
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 396
# KL-Divergence measure: [##################################################] 5000/5000
#
# query:# 397
# KL-Divergence measure: [########..........................................] 865/5000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-43-94b6bc0f0dfc> in <module>
#      11         '''parameters:'''
#      12         doc_id = pseudo_doc_list[query_id][j]
# ---> 13         prob = KL_Divergence(len(list(vocab_index.values())), docs_index[doc_id], word_query_prob, plsa_prob, bg_prob)
#      14         query_doc_prob[doc_id] = prob
#      15     rank_prob[query_list[i]] = rank(query_doc_prob, 5000, rev=False)
#
# KeyboardInterrupt:

# %%
    print(pseudo_doc_list[301])
# Out:
# ['FBIS4-41684', 'FBIS4-45564', 'FBIS4-26397', 'FBIS3-19199', 'FBIS3-19646', 'FBIS3-21961', 'FBIS4-46734', 'FBIS3-23986', 'FBIS3-41247', 'FBIS3-26415', 'FBIS4-43965', 'FBIS4-62079', 'FBIS4-7811', 'FBIS3-55219', 'FBIS4-61760', 'FT923-3929', 'FBIS3-60984', 'FBIS3-58028', 'FBIS3-58058', 'FBIS3-58055', 'FBIS4-54904', 'FBIS4-46846', 'FBIS4-67072', 'FBIS4-56982', 'FBIS4-33857', 'FBIS3-26597', 'FBIS3-41246', 'FBIS4-45333', 'FBIS3-55171', 'FBIS3-24145', 'FBIS4-64135', 'FBIS4-26902', 'FBIS3-46172', 'FBIS3-41103', 'FBIS3-41272', 'FBIS4-38364', 'FBIS4-45360', 'FBIS4-31295', 'FBIS3-21770', 'FBIS4-43533', 'FBIS3-46302', 'FBIS3-41285', 'FBIS3-42315', 'FBIS4-62084', 'FBIS3-21765', 'FBIS4-45477', 'FBIS4-2802', 'FBIS4-68801', 'FBIS4-43801', 'FBIS4-8957', 'FBIS4-21321', 'FBIS3-54773', 'FBIS4-47045', 'FBIS3-41387', 'FBIS3-31267', 'FBIS3-35561', 'FBIS3-24182', 'FBIS3-38070', 'FBIS3-60083', 'FBIS4-11948', 'FBIS4-26653', 'FBIS4-21166', 'FBIS4-12999', 'FBIS4-41687', 'FBIS3-60093', 'FBIS3-49567', 'FBIS3-24247', 'FBIS3-15586', 'FBIS4-45469', 'FBIS4-31645', 'FBIS3-19420', 'FBIS4-67209', 'FBIS4-52946', 'FBIS4-40805', 'FBIS4-46360', 'FBIS4-52601', 'FBIS3-24284', 'FBIS4-45563', 'FBIS4-3889', 'FBIS4-40308', 'FBIS3-58751', 'FBIS4-62695', 'FBIS3-21761', 'FBIS4-43152', 'FBIS4-49380', 'FBIS4-40934', 'LA020989-0127', 'FBIS4-66008', 'FBIS4-45239', 'FBIS4-21249', 'FBIS3-38878', 'FBIS4-65447', 'FBIS4-22377', 'FBIS4-21038', 'FBIS4-45336', 'FBIS4-38895', 'FBIS3-36385', 'FBIS4-26323', 'FBIS3-41298', 'FBIS3-32674', 'FBIS4-56992', 'FBIS4-67183', 'FBIS4-21335', 'FT943-16238', 'FBIS3-21886', 'FBIS3-22324', 'FBIS4-22235', 'FBIS3-21787', 'FBIS3-24318', 'FBIS4-46780', 'FT943-16477', 'FBIS3-22101', 'FBIS3-37399', 'FBIS4-9621', 'FT941-5449', 'FBIS4-47199', 'FBIS3-28711', 'FBIS3-41250', 'FBIS4-22768', 'FBIS4-21302', 'FBIS4-67492', 'FBIS4-56513', 'FBIS4-42499', 'LA102989-0027', 'FBIS4-61897', 'LA032790-0103', 'FBIS4-17426', 'FBIS4-13889', 'FBIS3-21941', 'FBIS3-21975', 'FBIS3-24288', 'FBIS4-50442', 'FBIS3-39240', 'FBIS3-21769', 'FBIS4-22214', 'FBIS3-60000', 'FBIS4-43797', 'FBIS3-41348', 'FBIS3-38466', 'FBIS3-41445', 'FBIS4-45571', 'FT924-227', 'FBIS3-35546', 'FBIS4-67227', 'FBIS3-16357', 'FBIS4-53424', 'FBIS4-67292', 'FBIS4-45383', 'FBIS3-60008', 'FBIS3-22088', 'FBIS4-26127', 'FBIS3-22049', 'FBIS4-26642', 'FBIS4-67334', 'FBIS4-27974', 'FBIS4-43552', 'FBIS4-45377', 'FBIS3-26112', 'FBIS3-2393', 'FBIS4-45458', 'FBIS4-28351', 'FBIS4-57987', 'FT941-3237', 'FBIS4-28925', 'FBIS3-24325', 'FBIS3-20551', 'FBIS4-26128', 'FBIS3-20552', 'FBIS4-20981', 'FBIS4-9746', 'FBIS4-18226', 'FBIS3-21750', 'FBIS4-47610', 'FBIS3-20171', 'FT931-16885', 'FBIS3-5872', 'FT944-12173', 'FBIS3-30843', 'FBIS4-47039', 'FBIS4-45375', 'FBIS3-24197', 'FBIS3-23331', 'FBIS4-34836', 'FT944-8297', 'FBIS4-28073', 'FBIS3-59206', 'FBIS4-22767', 'FBIS3-60124', 'FBIS4-10411', 'FT924-4782', 'FBIS4-62028', 'FBIS3-60111', 'FBIS3-32760', 'FBIS3-41406', 'FBIS3-42820', 'LA061190-0112', 'FBIS3-41169', 'FBIS4-22482', 'FBIS4-41825', 'FBIS4-41753', 'FBIS4-39617', 'FBIS3-45757', 'FBIS4-19393', 'FBIS4-28239', 'FBIS4-45307', 'FBIS4-68371', 'FBIS3-41211', 'FBIS4-28067', 'FBIS4-67027', 'FBIS4-15252', 'LA011190-0001', 'FBIS3-41121', 'FBIS3-21743', 'FBIS4-45235', 'FT943-3533', 'FBIS4-46425', 'FBIS4-42757', 'FBIS4-45419', 'LA051089-0084', 'FBIS3-34177', 'FBIS4-56467', 'FBIS4-67140', 'FBIS3-52033', 'FBIS3-41082', 'FBIS3-33001', 'FBIS4-24386', 'FBIS4-27476', 'FBIS4-67942', 'FBIS3-41320', 'FBIS4-45175', 'FBIS3-18733', 'LA040489-0112', 'FBIS3-50603', 'FBIS3-60065', 'FBIS3-12285', 'FT921-15491', 'FBIS4-40935', 'FBIS4-19851', 'LA052090-0143', 'FBIS4-67144', 'FBIS3-41973', 'FBIS3-15169', 'FBIS3-37478', 'LA082790-0022', 'FBIS3-23906', 'FBIS3-28080', 'LA071689-0134', 'FBIS3-33963', 'FBIS4-45257', 'FBIS3-41174', 'FBIS3-41071', 'FBIS4-67239', 'FBIS3-10717', 'FBIS3-10838', 'FBIS3-21884', 'FBIS4-3935', 'FT923-14709', 'FBIS4-41223', 'FBIS3-41253', 'FBIS4-46741', 'FBIS4-57322', 'FBIS3-60973', 'FBIS3-15170', 'FBIS3-12456', 'FBIS3-37727', 'FBIS3-45696', 'FBIS3 ...

# %%
    print(rank_prob['301'])
# Out:
# [('FBIS4-45564', 5.617091183427182), ('FBIS4-26397', 5.61710878436304), ('FBIS4-26653', 6.498337113407309), ('FBIS4-41684', 6.533684558822817), ('FBIS4-45563', 6.559966950461137), ('FBIS4-26902', 6.595361888972377), ('FBIS3-19199', 6.598010382862521), ('FBIS3-41247', 6.600930103503086), ('FBIS3-26415', 6.606502716574959), ('FBIS3-21961', 6.684119688155167), ('FBIS3-19646', 6.684149190533936), ('FBIS3-26597', 6.687827722971355), ('FBIS4-2802', 6.688392425361511), ('FBIS3-41246', 6.690684926240563), ('FBIS4-43965', 6.720297673147918), ('FBIS4-21166', 6.74302163300122), ('FBIS3-46172', 6.754885113679252), ('FBIS3-41103', 6.758808256443388), ('FBIS3-60984', 6.77141425852177), ('FBIS4-33857', 6.7729518942109355), ('FBIS3-46302', 6.784302220287814), ('FT923-3929', 6.787528614624192), ('FBIS3-58055', 6.7932384678132856), ('FBIS4-61760', 6.795709771962749), ('FBIS4-67209', 6.796892257754042), ('FBIS4-52946', 6.797389851627944), ('FBIS3-55219', 6.799880311615778), ('FBIS4-67072', 6.8083420087236854), ('FBIS4-56982', 6.809244296796691), ('FBIS4-46846', 6.818565431601681), ('FBIS3-23986', 6.820608615336265), ('FBIS3-58028', 6.823856284891319), ('FBIS3-58058', 6.824173522170256), ('FBIS4-45360', 6.837692717646852), ('FBIS3-41285', 6.840237462912961), ('FBIS3-42315', 6.84095235197506), ('FBIS4-45333', 6.857735434158253), ('FBIS3-60083', 6.8692458318446725), ('FBIS3-21765', 6.874411633516312), ('FBIS4-49380', 6.883177809354985), ('FBIS3-21770', 6.888652382349565), ('FBIS3-41272', 6.891626126458996), ('FBIS3-28711', 6.892036926346865), ('FBIS3-41250', 6.89253168889569), ('FBIS4-7811', 6.894908380168983), ('FBIS4-46734', 6.895033047443415), ('FBIS4-12999', 6.904813345612299), ('FBIS4-8957', 6.917147851433144), ('FBIS3-41298', 6.92090208292185), ('FBIS3-32674', 6.9210301548542015), ('FBIS4-21321', 6.921833247388059), ('FBIS4-45477', 6.927576448124014), ('FBIS4-38895', 6.930819132475153), ('FBIS4-45336', 6.930835531830822), ('FBIS4-43801', 6.932096912489452), ('FBIS4-31295', 6.93225251494033), ('FBIS4-54904', 6.9326486899652835), ('FBIS4-62079', 6.933155121879054), ('FBIS3-21886', 6.946120121093152), ('FBIS3-24145', 6.946930065765073), ('FBIS3-41387', 6.948843737187718), ('FBIS4-52601', 6.948944626760556), ('FBIS3-31267', 6.950669673762326), ('FBIS4-43533', 6.951710324375348), ('FBIS3-60093', 6.9518287082282555), ('FBIS3-49567', 6.957234308059589), ('FBIS4-38364', 6.964856733704149), ('FBIS3-2393', 6.9670861638769415), ('FBIS4-21335', 6.968490633025004), ('FBIS3-21750', 6.978902958241144), ('FBIS4-22377', 6.9789926491767975), ('FBIS4-45458', 6.981950217341422), ('FBIS4-62695', 6.982414562503762), ('FBIS4-21038', 6.986162475146914), ('FBIS4-64135', 6.987037093426032), ('FBIS3-21787', 6.987842560876297), ('FBIS4-28925', 6.990544328755375), ('FBIS4-46360', 6.992958233496675), ('FBIS3-21761', 7.0100445672935185), ('FBIS3-60000', 7.011596195015624), ('FBIS4-45469', 7.020849587899362), ('FBIS4-31645', 7.022129754112074), ('FBIS3-21975', 7.027331878593372), ('FBIS3-26112', 7.02779126898122), ('FBIS3-24288', 7.027947004986843), ('FBIS3-55171', 7.03221992341663), ('FBIS4-26323', 7.041816993306518), ('FBIS3-60008', 7.043778314143633), ('FBIS3-15586', 7.0493004479238515), ('FBIS4-62084', 7.054610917962382), ('FBIS4-26642', 7.061921066791706), ('FBIS4-45239', 7.065552704858728), ('FBIS3-35561', 7.069247863747568), ('FBIS4-47610', 7.076569936375277), ('FBIS3-19420', 7.077364832642206), ('FBIS4-21302', 7.087253032995027), ('FBIS4-66008', 7.097546891819549), ('FBIS4-53424', 7.099455442554578), ('FBIS4-67292', 7.09953970162355), ('FBIS4-45377', 7.101048410949743), ('FBIS4-27974', 7.101491930386122), ('FBIS4-11948', 7.101751541100626), ('FBIS3-24247', 7.1041734624750505), ('FBIS4-45375', 7.105137079187711), ('FBIS3-22049', 7.1097366975334255), ('FBIS4-28073', 7.112636126187295), ('FBIS3-45757', 7.119223502681087), ('FBIS3-24284', 7.11947707471145), ('FBIS3-38070', 7.126326605862718), ('FBIS4-47045', 7.126425195550836), ('FBIS3-22324', 7.127849281876146), ('FBIS ...

# %%
    with open('smm_model.csv', 'w', encoding='UTF-8') as f:
        f.write("Query,RetrievedDocuments\n")
        for query_id in rank_prob:
            # output
            f.write("%s," % query_id)
            for rank_id, rank_score in rank_prob[query_id]:           
                # print(rank_id, rank_score)
                f.write("%s " % rank_id)
#             for rank_id in after_doc[int(query_id)]:
#                 f.write("%s " % rank_id)
            f.write('\n')
    f.close()
